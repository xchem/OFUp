# %% [markdown]
# # KALRNA: Scoring initial poses

# %% [markdown]
# ## 1. Scoring 3D aligned structures (fragment-based approach)
# To evaluate the quality of the alignments produced (see 20190626-KALRNA_genetate_initial_confs), two scores were used to compare the aligned conformations for each follow-up candidate to their respective hit molecule:
# - SuCOS score: The SuCOS score is an open-source shape and chemical feature overlap metric
# - Tanimoto shape similarity: This score compares the similarity in shape between two molecules
#
# The best conformation for each score is taken as the best initial geometry guess for each candidate molecule.
#
# The results, indicating the best conformation for each candidate molecule for both the 'surprise' and 'similar' sets are returned as a dictionary, which can be displayed and manipulated by pandas. The dictionary gives the best score for each of the two scores described, the conformer-containing sdf file, and the index of the molecule in the sdf file for both scores, so that the conformations can be easily accessed from the original aligned conformer sdf file
#
# ### Code (adapted from https://bitbucket.org/Susanhleung/sucos/src/master/calc_SuCOS.py):

# %%
import argparse, os, gzip
import glob
import numpy as np
import rdkit
from rdkit import Chem
from rdkit.Chem import AllChem, rdShapeHelpers
from rdkit.Chem.FeatMaps import FeatMaps
from rdkit import RDConfig
from rdkit.Chem import Draw
from joblib import Parallel, delayed
import multiprocessing
import operator

fdef = AllChem.BuildFeatureFactory(os.path.join(RDConfig.RDDataDir, 'BaseFeatures.fdef'))

fmParams = {}
for k in fdef.GetFeatureFamilies():
    fparams = FeatMaps.FeatMapParams()
    fmParams[k] = fparams

keep = ('Donor', 'Acceptor', 'NegIonizable', 'PosIonizable', 'ZnBinder',
        'Aromatic', 'Hydrophobe', 'LumpedHydrophobe')

def get_FeatureMapScore(small_m, large_m, score_mode=FeatMaps.FeatMapScoreMode.All):
    featLists = []
    for m in [small_m, large_m]:
        rawFeats = fdef.GetFeaturesForMol(m)
        # filter that list down to only include the ones we're intereted in
        featLists.append([f for f in rawFeats if f.GetFamily() in keep])
    fms = [FeatMaps.FeatMap(feats=x, weights=[1] * len(x), params=fmParams) for x in featLists]
    fms[0].scoreMode = score_mode
    fm_score = fms[0].ScoreFeats(featLists[1]) / min(fms[0].GetNumFeatures(), len(featLists[1]))
    return fm_score

def sucos_mol_to_mol(mol1, mol2, score_mode=FeatMaps.FeatMapScoreMode.All):
    ref = Chem.AddHs(mol1)
    prb = Chem.AddHs(mol2)
    
    fm_score = get_FeatureMapScore(ref, prb, score_mode)
    fm_score = np.clip(fm_score, 0, 1)

    protrude_dist = rdShapeHelpers.ShapeProtrudeDist(ref, prb,
            allowReordering=False)
    protrude_dist = np.clip(protrude_dist, 0, 1)

    SuCOS_score = 0.5*fm_score + 0.5*(1 - protrude_dist)
    
    return SuCOS_score


def score(ref_file, prb_file, score_mode=FeatMaps.FeatMapScoreMode.All, p=False):
    reflig = Chem.MolFromMolFile(ref_file, sanitize=True)
    ref = Chem.AddHs(reflig)
    prb_mols = Chem.SDMolSupplier(prb_file, sanitize=True)
    prb_mols = [x for x in prb_mols if x]
    idx = 0
    
    results_sucos = {}
    results_tani = {}
    
    smi_mol = Chem.MolToSmiles(prb_mols[0])
    
    for prb_mol in prb_mols:
        
        prb = Chem.AddHs(prb_mol)
                
        fm_score = get_FeatureMapScore(ref, prb, score_mode)
        fm_score = np.clip(fm_score, 0, 1)
        
        protrude_dist = rdShapeHelpers.ShapeProtrudeDist(ref, prb,
                allowReordering=False)
        protrude_dist = np.clip(protrude_dist, 0, 1)
        
        SuCOS_score = 0.5*fm_score + 0.5*(1 - protrude_dist)
        tanimoto_score = Chem.rdShapeHelpers.ShapeTanimotoDist(ref, prb)
        
        results_sucos[str(idx)] = SuCOS_score
        results_tani[str(idx)] = tanimoto_score
        
        if p:
        
            print ("********************************")
            print ("index: " + str(idx))
            print ("SuCOS score:\t%f" % SuCOS_score)
            print ("Tani score:\t%f" % tanimoto_score)
            print ("********************************")
        
        idx+=1

    return results_sucos, results_tani, smi_mol, prb_mols, reflig


def select_highest(results, number):
    ids = []
    r = results
    while len(ids)<number:
        i = max(results.items(), key=operator.itemgetter(1))[0]
        ids.append(int(i))
        r.pop(i, None)
    return ids

def select_lowest(results, number):
    ids = []
    r = results
    while len(ids)<number:
        i = min(results.items(), key=operator.itemgetter(1))[0]
        ids.append(int(i))
        r.pop(i, None)
    return ids

def score_all_confs(hit_file_directory, initial_hit, all_confs_paths):

    all_results_dict = {
        'candidate_name': [],
        'candidate_smiles': [],
        'candidate_conformers_file': [],
        'initial_hit': [],
        'best_sucos': [],
        'best_sucos_id': [],
        'best_tanimoto': [],
        'best_tanimoto_id': [],
    }
    
    for i in range(0, len(all_confs_paths)):
        results_sucos, results_tani, smiles, prb_mols, reflig = score(ref_file=initial_hit, prb_file=all_confs_paths[i])
        print('running ' + str(i) + '/' + str(len(all_confs_paths)))
        # best sucos socre and id
        r = results_sucos.copy()
        idx = select_highest(r, 1)[0]
        sucos_score = results_sucos[str(idx)]
        # best tanimoto socre and id
        s = results_tani.copy()
        idy = select_lowest(s, 1)[0]
        tani_score = results_tani[str(idy)]

        all_results_dict['candidate_name'].append(all_confs_paths[i].split('/')[-1].replace('_confs_aligned.sdf', ''))
        all_results_dict['candidate_smiles'].append(smiles)
        all_results_dict['candidate_conformers_file'].append(all_confs_paths[i])
        all_results_dict['initial_hit'].append(initial_hit.split('/')[-1])
        all_results_dict['best_sucos'].append(sucos_score)
        all_results_dict['best_sucos_id'].append(idx)
        all_results_dict['best_tanimoto'].append(tani_score)
        all_results_dict['best_tanimoto_id'].append(idy)

    return all_results_dict

# %%
hit_file_directory = '/data/GDP_frags/GDP_frag2'
initial_hit = '/data/GDP_frags/GDP.sdf'
all_confs_paths = glob.glob(os.path.join(hit_file_directory, '*_confs_aligned.sdf'))
print(all_confs_paths)

all_results_dict = score_all_confs(hit_file_directory=hit_file_directory, 
                                   initial_hit=initial_hit, 
                                   all_confs_paths=all_confs_paths)
# Out:
# ['/data/GDP_frags/GDP_frag2/GDP_frag2-surprise-rsn_535_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-similar-rsn_74_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-similar-rsn_664_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-similar-rsn_983_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-similar-rsn_499_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-similar-rsn_303_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-surprise-rsn_786_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-surprise-rsn_861_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-similar-rsn_780_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-similar-rsn_867_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-surprise-rsn_42_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-similar-rsn_829_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-surprise-rsn_305_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-similar-rsn_533_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-surprise-rsn_662_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-surprise-rsn_985_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-surprise-rsn_231_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-similar-rsn_160_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-surprise-rsn_756_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-similar-rsn_407_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-similar-rsn_953_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-surprise-rsn_718_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-similar-rsn_449_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-surprise-rsn_92_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-similar-rsn_279_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-surprise-rsn_955_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-surprise-rsn_128_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-similar-rsn_750_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-surprise-rsn_401_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-similar-rsn_237_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-surprise-rsn_166_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-similar-rsn_461_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-surprise-rsn_730_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-similar-rsn_106_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-surprise-rsn_257_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-surprise-rsn_899_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-surprise-rsn_583_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-similar-rsn_935_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-similar-rsn_148_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-surprise-rsn_219_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-similar-rsn_585_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-surprise-rsn_933_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-surprise-rsn_429_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-similar-rsn_778_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-surprise-rsn_100_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-similar-rsn_251_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-surprise-rsn_467_confs_aligned.sdf', '/data/GDP_frags/GDP_frag2/GDP_frag2-similar-rsn
# running 1979/1998
# running 1980/1998
# running 1981/1998
# running 1982/1998
# running 1983/1998
# running 1984/1998
# running 1985/1998
# running 1986/1998
# running 1987/1998
# running 1988/1998
# running 1989/1998
# running 1990/1998
# running 1991/1998
# running 1992/1998
# running 1993/1998
# running 1994/1998
# running 1995/1998
# running 1996/1998
# running 1997/1998

# %% [markdown]
# ### 1.1 Evaluating the scores of aligned conformers
#
# The results dictionary from above can be displayed by pandas. Showing the resulting data, sorted on 'best_sucos' shows that (according to sucos) the molecules we have generated are very similar, in shape and feature, to the starting hit molecule.
#
# We can also see that the majority of the top ranked compounds are from the 'similar' set - which is to be expected. To add some diversity to the molecules that will be investigated further, the two sets have been separated back out for analysis (and the results saved out as csv files so we can look again later).

# %%
import pandas as pd
# create dataframe from results of scoring alignments
df = pd.DataFrame.from_dict(all_results_dict)

# top 500 compounds from each search set(similar/surprise) and score(sucos/tanimoto)
best_sucos_similar = df[df['candidate_name'].str.contains("similar")].sort_values(by=['best_sucos'], ascending=False).head(500)
best_tanimoto_similar = df[df['candidate_name'].str.contains("similar")].sort_values(by=['best_tanimoto'], ascending=True).head(500)
best_sucos_surprise = df[df['candidate_name'].str.contains("surprise")].sort_values(by=['best_sucos'], ascending=False).head(500)
best_tanimoto_surprise = df[df['candidate_name'].str.contains("surprise")].sort_values(by=['best_tanimoto'], ascending=True).head(500)

# save the top 500 as csv files
best_sucos_similar.to_csv('/data/GDP_frags/GDP_frag2/500_similar_sucos.csv')
best_tanimoto_similar.to_csv('/data/GDP_frags/GDP_frag2/500_similar_tanimoto.csv')
best_sucos_surprise.to_csv('/data/GDP_frags/GDP_frag2/500_surprise_sucos.csv')
best_tanimoto_surprise.to_csv('/data/GDP_frags/GDP_frag2/500_surprise_tanimoto.csv')

# display results frame
df.sort_values(by=['best_sucos'], ascending=False)
# Out:
#                   candidate_name               candidate_smiles  \
# 730    GDP_frag2-similar-rsn_566      CNC(=S)N1CCOC(C(F)(F)F)C1
# 1364   GDP_frag2-similar-rsn_610  CNC(=S)N1CC(CO)OC(C(F)(F)F)C1
# 7     GDP_frag2-surprise-rsn_861                      NN1CCOCC1
# 843    GDP_frag2-similar-rsn_729            CNC(=S)N1CCOC(CO)C1
# 233   GDP_frag2-surprise-rsn_635                CON1CC[NH2+]CC1
# 207    GDP_frag2-similar-rsn_206                      OC1COCC1F
# 402    GDP_frag2-similar-rsn_784                      OC1COCC1O
# 137   GDP_frag2-surprise-rsn_404               FC(F)(F)COCC1CO1
# 169    GDP_frag2-similar-rsn_550               COCC1C[NH2+]CCO1
# 1737  GDP_frag2-surprise-rsn_969                  OCCOCC(F)(F)F
# 198     GDP_frag2-surprise-rsn_6             CNC(=S)N(C)CCOCCOC
# 807    GDP_frag2-surprise-rsn_69     CNC(=S)N1CC(CO)CC(OCCOC)C1
# 850    GDP_frag2-similar-rsn_430              CNC(=S)NC1COCC1OC
# 786    GDP_frag2-similar-rsn_163                      COCC(O)CO
# 1543  GDP_frag2-surprise-rsn_396                COCC(O)C(F)(F)F
# 671    GDP_frag2-similar-rsn_362         CNC(=S)N1CCC(CO)(OC)C1
# 48     GDP_frag2-similar-rsn_365            CNC(=S)N1CCOCC(O)C1
# 380    GDP_frag2-similar-rsn_919                       COCC1CO1
# 290    GDP_frag2-similar-rsn_107                   [NH3+]C1COC1
# 257    GDP_frag2-similar-rsn_982                     OCC1COCCO1
# 620    GDP_frag2-similar-rsn_563                C[NH2+]C1COCC1O
# 1116  GDP_frag2-surprise-rsn_474                    COCCOCCOCCO
# 1315   GDP_frag2-similar-rsn_869                      COC(CO)CO
# 866   GDP_frag2-surprise-rsn_260         CCOCCOC1CCN(C(=S)NC)C1
# 1430   GDP_frag2-similar-rsn_125              C[NH+](C)C1COCC1O
# 692    GDP_frag2-similar-rsn_932             CNC(=S)N(C)C1CCOC1
# 779    GDP_frag2-similar-rsn_753                 OCC1(CO)COCCO1
# 1266  GDP_frag2-surprise-rsn_323       CNC(=S)NC1COCC1[NH+](C)C
# 845    GDP_frag2-similar-rsn_964                        OCC1CO1
# 2      GDP_frag2-similar-rsn_664            CNC(=O)N1CCOC(OC)C1
# ...                          ...                            ...
# 103   GDP_frag2-surprise-rsn_453                    CCC1CCCC1=O
# 382   GDP_frag2-surprise-rsn_235                O=C(CCl)C1CCCC1
# 1424  GDP_frag2-surprise-rsn_669                      NOC1CCCC1
# 1498    GDP_frag2-surprise-rsn_8                    C=CC1CCOCC1
# 1710   GDP_frag2-similar-rsn_873               CC1CNS(=O)(=O)C1
# 634    GDP_frag2-similar-rsn_719                  CC(C)C1(C)CO1
# 826   GDP_frag2-surprise-rsn_856            CC1(C(=O)[O-])CCCO1
# 483    GDP_frag2-surprise-rsn_14                    CC1CCCCC1=O
# 1069   GDP_frag2-similar-rsn_826                   CS(=O)CC1CC1
# 598   GDP_frag2-surprise-rsn_249                  CC(=O)C1CCCS1
# 1067  GDP_frag2-surprise-rsn_820                  CC1CCC(C=O)C1
# 275   GDP_frag2-surprise-rsn_230                  CC1CCC(=O)CC1
# 590   GDP_frag2-surprise-rsn_150                      NOCC1CCC1
# 1102   GDP_frag2-similar-rsn_224                  N=S1(=O)CCCC1
# 593   GDP_frag2-surprise-rsn_760                  CC(C=O)C1CCC1
# 262   GDP_frag2-surprise-rsn_663            CCC1(C(=O)[O-])COC1
# 524   GDP_frag2-surprise-rsn_164               CC1(C)CC1C(=O)Cl
# 329    GDP_frag2-similar-rsn_506                  CC(C)(C)C1CO1
# 1669    GDP_frag2-similar-rsn_32                   N=S1(=O)CCC1
# 1331  GDP_frag2-surprise-rsn_359                    CC1CCCC1C=O
# 563   GDP_frag2-surprise-rsn_551                  CC(=O)C1CCCC1
# 149   GDP_frag2-surprise-rsn_667                  CC(=O)CC1CCC1
# 1662  GDP_frag2-surprise-rsn_497                  CCC(=O)C1CCC1
# 401    GDP_frag2-similar-rsn_863                    CC1(CON)CC1
# 374   GDP_frag2-surprise-rsn_318               CC1(C(=O)Cl)CCC1
# 1603   GDP_frag2-similar-rsn_727                   CS(=O)C1CCC1
# 739   GDP_frag2-surprise-rsn_834                    CC1(C=O)CC1
# 294   GDP_frag2-surprise-rsn_466                CC(=O)C1CC12CC2
# 1817  GDP_frag2-surprise-rsn_672              CC1(C)COC(CCl)=N1
# 1692   GDP_frag2-similar-rsn_223             [NH3+]C12COC(C1)C2
#
#                               candidate_conformers_file initial_hit  \
# 730   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 
# 1603    0.208402             69       0.688308                97
# 739     0.202492              4       0.757527                43
# 294     0.198406              6       0.685445                 3
# 1817    0.179828             60       0.676524                62
# 1692    0.148926             52       0.772900                62
#
# [1998 rows x 8 columns]

# %% [markdown]
# ### 1.2 Evaluating the diversity of the top-scoring candidates
#
# Given the SuCos scores (and tanimoto scores) of the highest-scored compounds are extremely similar to each other (e.g. the top 14 compounds all have a SuCOS score of 0.98), it is likely that the compounds themselves are very similar to each other, and do not represent a chemically-diverse set.
#
# To evaluate this, the sucos score for each of the top 500 compounds (scored with sucos) with every other compound  for both the similar and surprise sets was calculated

# %%
from rdkit.Chem.rdMolDescriptors import GetMorganFingerprint
from rdkit import DataStructs
from rdkit.SimDivFilters.rdSimDivPickers import MaxMinPicker

def mols_from_df(df, files_col='candidate_conformers_file', id_col='best_sucos_id'):
    mols = [Chem.SDMolSupplier(f)[int(idx)] for f, idx in [(df.iloc[i][files_col], 
                                                            df.iloc[i][id_col]) 
                                                           for i in range(0, len(df))]]
    return mols

def mols_from_morgan(mols, number):
    
    fps = [GetMorganFingerprint(x,3) for x in mols]
    
    def distij(i,j,fps=fps):
        return 1-DataStructs.DiceSimilarity(fps[i],fps[j])
    
    nfps = len(fps)
    picker = MaxMinPicker()
    pickIndices = picker.LazyPick(distij,nfps,number,seed=23)
    picks = [mols[x] for x in pickIndices]
    
    return picks, pickIndices

def compare_mols_sucos(df):
    mat = []
    i = 0
    for mol1 in df:
        print('eval mol ' + str(i))
        arr = []
        for mol2 in df:
            arr.append(sucos_mol_to_mol(mol1=mol1, mol2=mol2))
        mat.append(arr)
        i += 1
    return mat

# %%
top_500_similar_mols = mols_from_df(best_sucos_similar)
top_500_similar_mat = compare_mols_sucos(top_500_similar_mols)
# Out:
# eval mol 0
# eval mol 1
# eval mol 2
# eval mol 3
# eval mol 4
# eval mol 5
# eval mol 6
# eval mol 7
# eval mol 8
# eval mol 9
# eval mol 10
# eval mol 11
# eval mol 12
# eval mol 13
# eval mol 14
# eval mol 15
# eval mol 16
# eval mol 17
# eval mol 18
# eval mol 19
# eval mol 20
# eval mol 21
# eval mol 22
# eval mol 23
# eval mol 24
# eval mol 25
# eval mol 26
# eval mol 27
# eval mol 28
# eval mol 29
# eval mol 30
# eval mol 31
# eval mol 32
# eval mol 33
# eval mol 34
# eval mol 35
# eval mol 36
# eval mol 37
# eval mol 38
# eval mol 39
# eval mol 40
# eval mol 41
# eval mol 42
# eval mol 43
# eval mol 44
# eval mol 45
# eval mol 46
# eval mol 47
# eval mol 48
# eval mol 49
# eval mol 50
# eval mol 51
# eval mol 52
# eval mol 53
# eval mol 54
# eval mol 55
# eval mol 56
# eval mol 57
# eval mol 58
# eval mol 59
# eval mol 60
# eval mol 61
# eval mol 62
# eval mol 63
# eval mol 64
# eval mol 65
# eval mol 66
# eval mol 67
# eval mol 68
# eval mol 69
# eval mol 70
# eval mol 71
# eval mol 72
# eval mol 73
# eval mol 74
# eval mol 75
# eval mol 76
# eval mol 77
# eval mol 78
# eval mol 79
# eval mol 80
# eval mol 81
# eval mol 82
# eval mol 83
# eval mol 84
# eval mol 85
# eval mol 86
# eval mol 87
# eval mol 88
# eval mol 89
# eval mol 90
# eval mol 91
# eval mol 92
# eval mol 93
# eval mol 94
# eval mol 95
# eval mol 96
# eval mol 97
# eval mol 98
# eval mol 99
# eval mol 100
# eval mol 101
# eval mol 102
# eval mol 103
# eval mol 104
# eval mol 105
# eval mol 106
# eval mol 107
# eval mol 108
# eval mol 109
# eval mol 110
# eval mol 111
# eval mol 112
# eval mol 113
# eval mol 114
# eval mol 115
# eval mol 116
# eval mol 117
# eval mol 118
# eval mol 119
# eval mol 120
# eval mol 121
# eval mol 122
# eval mol 123
# eval mol 124
# eval mol 125
# eval mol 126
# eval mol 127
# eval mol 128
# eval mol 129
# eval mol 130
# eval mol 131
# eval mol 132
# eval mol 133
# eval mol 134
# eval mol 135
# eval mol 136
# eval mol 137
# eval mol 138
# eval mol 139
# eval mol 140
# eval mol 141
# eval mol 142
# eval mol 143
# eval mol 144
# eval mol 145
# eval mol 146
# eval mol 147
# eval mol 148
# eval mol 149
# eval mol 150
# eval mol 151
# eval mol 152
# eval mol 153
# eval mol 154
# eval mol 155
# eval mol 156
# eval mol 157
# eval mol 158
# eval mol 159
# eval mol 160
# eval mol 161
# eval mol 162
# eval mol 163
# eval mol 164
# eval mol 165
# eval mol 166
# eval mol 167
# eval mol 168
# eval mol 169
# eval mol 170
# eval mol 171
# eval mol 172
# eval mol 173
# eval mol 174
# eval mol 175
# eval mol 176
# eval mol 177
# eval mol 178
# eval mol 179
# eval mol 180
# eval mol 181
# eval mol 182
# eval mol 183
# eval mol 184
# eval mol 185
# eval mol 186
# eval mol 187
# eval mol 188
# eval mol 189
# eval mol 190
# eval mol 191
# eval mol 192
# eval mol 193
# eval mol 194
# eval mol 195
# eval mol 196
# eval mol 197
# eval mol 198
# eval mol 199
# eval mol 200
# eval mol 201
# eval mol 202
# eval mol 203
# eval mol 204
# eval mol 205
# eval mol 206
# eval mol 207
# eval mol 208
# eval mol 209
# eval mol 210
# eval mol 211
# eval mol 212
# eval mol 213
# eval mol 214
# eval mol 215
# eval mol 216
# eval mol 217
# eval mol 218
# eval mol 219
# eval mol 220
# eval mol 221
# eval mol 222
# eval mol 223
# eval mol 224
# eval mol 225
# eval mol 226
# eval mol 227
# eval mol 228
# eval mol 229
# eval mol 230
# eval mol 231
# eval mol 232
# eval mol 233
# eval mol 234
# eval mol 235
# eval mol 236
# eval mol 237
# eval mol 238
# eval mol 239
# eval mol 240
# eval mol 241
# eval mol 242
# eval mol 243
# eval mol 244
# eval mol 245
# eval mol 246
# eval mol 247
# eval mol 248
# eval mol 249
# eval mol 250
# eval mol 251
# eval mol 252
# eval mol 253
# eval mol 254
# eval mol 255
# eval mol 256
# eval mol 257
# eval mol 258
# eval mol 259
# eval mol 260
# eval mol 261
# eval mol 262
# eval mol 263
# eval mol 264
# eval mol 265
# eval mol 266
# eval mol 267
# eval mol 268
# eval mol 269
# eval mol 270
# eval mol 271
# eval mol 272
# eval mol 273
# eval mol 274
# eval mol 275
# eval mol 276
# eval mol 277
# eval mol 278
# eval mol 279
# eval mol 280
# eval mol 281
# eval mol 282
# eval mol 283
# eval mol 284
# eval mol 285
# eval mol 286
# eval mol 287
# eval mol 288
# eval mol 289
# eval mol 290
# eval mol 291
# eval mol 292
# eval mol 293
# eval mol 294
# eval mol 295
# eval mol 296
# eval mol 297
# eval mol 298
# eval mol 299
# eval mol 300
# eval mol 301
# eval mol 302
# eval mol 303
# eval mol 304
# eval mol 305
# eval mol 306
# eval mol 307
# eval mol 308
# eval mol 309
# eval mol 310
# eval mol 311
# eval mol 312
# eval mol 313
# eval mol 314
# eval mol 315
# eval mol 316
# eval mol 317
# eval mol 318
# eval mol 319
# eval mol 320
# eval mol 321
# eval mol 322
# eval mol 323
# eval mol 324
# eval mol 325
# eval mol 326
# eval mol 327
# eval mol 328
# eval mol 329
# eval mol 330
# eval mol 331
# eval mol 332
# eval mol 333
# eval mol 334
# eval mol 335
# eval mol 336
# eval mol 337
# eval mol 338
# eval mol 339
# eval mol 340
# eval mol 341
# eval mol 342
# eval mol 343
# eval mol 344
# eval mol 345
# eval mol 346
# eval mol 347
# eval mol 348
# eval mol 349
# eval mol 350
# eval mol 351
# eval mol 352
# eval mol 353
# eval mol 354
# eval mol 355
# eval mol 356
# eval mol 357
# eval mol 358
# eval mol 359
# eval mol 360
# eval mol 361
# eval mol 362
# eval mol 363
# eval mol 364
# eval mol 365
# eval mol 366
# eval mol 367
# eval mol 368
# eval mol 369
# eval mol 370
# eval mol 371
# eval mol 372
# eval mol 373
# eval mol 374
# eval mol 375
# eval mol 376
# eval mol 377
# eval mol 378
# eval mol 379
# eval mol 380
# eval mol 381
# eval mol 382
# eval mol 383
# eval mol 384
# eval mol 385
# eval mol 386
# eval mol 387
# eval mol 388
# eval mol 389
# eval mol 390
# eval mol 391
# eval mol 392
# eval mol 393
# eval mol 394
# eval mol 395
# eval mol 396
# eval mol 397
# eval mol 398
# eval mol 399
# eval mol 400
# eval mol 401
# eval mol 402
# eval mol 403
# eval mol 404
# eval mol 405
# eval mol 406
# eval mol 407
# eval mol 408
# eval mol 409
# eval mol 410
# eval mol 411
# eval mol 412
# eval mol 413
# eval mol 414
# eval mol 415
# eval mol 416
# eval mol 417
# eval mol 418
# eval mol 419
# eval mol 420
# eval mol 421
# eval mol 422
# eval mol 423
# eval mol 424
# eval mol 425
# eval mol 426
# eval mol 427
# eval mol 428
# eval mol 429
# eval mol 430
# eval mol 431
# eval mol 432
# eval mol 433
# eval mol 434
# eval mol 435
# eval mol 436
# eval mol 437
# eval mol 438
# eval mol 439
# eval mol 440
# eval mol 441
# eval mol 442
# eval mol 443
# eval mol 444
# eval mol 445
# eval mol 446
# eval mol 447
# eval mol 448
# eval mol 449
# eval mol 450
# eval mol 451
# eval mol 452
# eval mol 453
# eval mol 454
# eval mol 455
# eval mol 456
# eval mol 457
# eval mol 458
# eval mol 459
# eval mol 460
# eval mol 461
# eval mol 462
# eval mol 463
# eval mol 464
# eval mol 465
# eval mol 466
# eval mol 467
# eval mol 468
# eval mol 469
# eval mol 470
# eval mol 471
# eval mol 472
# eval mol 473
# eval mol 474
# eval mol 475
# eval mol 476
# eval mol 477
# eval mol 478
# eval mol 479
# eval mol 480
# eval mol 481
# eval mol 482
# eval mol 483
# eval mol 484
# eval mol 485
# eval mol 486
# eval mol 487
# eval mol 488
# eval mol 489
# eval mol 490
# eval mol 491
# eval mol 492
# eval mol 493
# eval mol 494
# eval mol 495
# eval mol 496
# eval mol 497
# eval mol 498
# eval mol 499

# %%
top_500_surprise_mols = mols_from_df(best_sucos_surprise)
top_500_surprise_mat = compare_mols_sucos(top_500_surprise_mols)
# Out:
# eval mol 0
# eval mol 1
# eval mol 2
# eval mol 3
# eval mol 4
# eval mol 5
# eval mol 6
# eval mol 7
# eval mol 8
# eval mol 9
# eval mol 10
# eval mol 11
# eval mol 12
# eval mol 13
# eval mol 14
# eval mol 15
# eval mol 16
# eval mol 17
# eval mol 18
# eval mol 19
# eval mol 20
# eval mol 21
# eval mol 22
# eval mol 23
# eval mol 24
# eval mol 25
# eval mol 26
# eval mol 27
# eval mol 28
# eval mol 29
# eval mol 30
# eval mol 31
# eval mol 32
# eval mol 33
# eval mol 34
# eval mol 35
# eval mol 36
# eval mol 37
# eval mol 38
# eval mol 39
# eval mol 40
# eval mol 41
# eval mol 42
# eval mol 43
# eval mol 44
# eval mol 45
# eval mol 46
# eval mol 47
# eval mol 48
# eval mol 49
# eval mol 50
# eval mol 51
# eval mol 52
# eval mol 53
# eval mol 54
# eval mol 55
# eval mol 56
# eval mol 57
# eval mol 58
# eval mol 59
# eval mol 60
# eval mol 61
# eval mol 62
# eval mol 63
# eval mol 64
# eval mol 65
# eval mol 66
# eval mol 67
# eval mol 68
# eval mol 69
# eval mol 70
# eval mol 71
# eval mol 72
# eval mol 73
# eval mol 74
# eval mol 75
# eval mol 76
# eval mol 77
# eval mol 78
# eval mol 79
# eval mol 80
# eval mol 81
# eval mol 82
# eval mol 83
# eval mol 84
# eval mol 85
# eval mol 86
# eval mol 87
# eval mol 88
# eval mol 89
# eval mol 90
# eval mol 91
# eval mol 92
# eval mol 93
# eval mol 94
# eval mol 95
# eval mol 96
# eval mol 97
# eval mol 98
# eval mol 99
# eval mol 100
# eval mol 101
# eval mol 102
# eval mol 103
# eval mol 104
# eval mol 105
# eval mol 106
# eval mol 107
# eval mol 108
# eval mol 109
# eval mol 110
# eval mol 111
# eval mol 112
# eval mol 113
# eval mol 114
# eval mol 115
# eval mol 116
# eval mol 117
# eval mol 118
# eval mol 119
# eval mol 120
# eval mol 121
# eval mol 122
# eval mol 123
# eval mol 124
# eval mol 125
# eval mol 126
# eval mol 127
# eval mol 128
# eval mol 129
# eval mol 130
# eval mol 131
# eval mol 132
# eval mol 133
# eval mol 134
# eval mol 135
# eval mol 136
# eval mol 137
# eval mol 138
# eval mol 139
# eval mol 140
# eval mol 141
# eval mol 142
# eval mol 143
# eval mol 144
# eval mol 145
# eval mol 146
# eval mol 147
# eval mol 148
# eval mol 149
# eval mol 150
# eval mol 151
# eval mol 152
# eval mol 153
# eval mol 154
# eval mol 155
# eval mol 156
# eval mol 157
# eval mol 158
# eval mol 159
# eval mol 160
# eval mol 161
# eval mol 162
# eval mol 163
# eval mol 164
# eval mol 165
# eval mol 166
# eval mol 167
# eval mol 168
# eval mol 169
# eval mol 170
# eval mol 171
# eval mol 172
# eval mol 173
# eval mol 174
# eval mol 175
# eval mol 176
# eval mol 177
# eval mol 178
# eval mol 179
# eval mol 180
# eval mol 181
# eval mol 182
# eval mol 183
# eval mol 184
# eval mol 185
# eval mol 186
# eval mol 187
# eval mol 188
# eval mol 189
# eval mol 190
# eval mol 191
# eval mol 192
# eval mol 193
# eval mol 194
# eval mol 195
# eval mol 196
# eval mol 197
# eval mol 198
# eval mol 199
# eval mol 200
# eval mol 201
# eval mol 202
# eval mol 203
# eval mol 204
# eval mol 205
# eval mol 206
# eval mol 207
# eval mol 208
# eval mol 209
# eval mol 210
# eval mol 211
# eval mol 212
# eval mol 213
# eval mol 214
# eval mol 215
# eval mol 216
# eval mol 217
# eval mol 218
# eval mol 219
# eval mol 220
# eval mol 221
# eval mol 222
# eval mol 223
# eval mol 224
# eval mol 225
# eval mol 226
# eval mol 227
# eval mol 228
# eval mol 229
# eval mol 230
# eval mol 231
# eval mol 232
# eval mol 233
# eval mol 234
# eval mol 235
# eval mol 236
# eval mol 237
# eval mol 238
# eval mol 239
# eval mol 240
# eval mol 241
# eval mol 242
# eval mol 243
# eval mol 244
# eval mol 245
# eval mol 246
# eval mol 247
# eval mol 248
# eval mol 249
# eval mol 250
# eval mol 251
# eval mol 252
# eval mol 253
# eval mol 254
# eval mol 255
# eval mol 256
# eval mol 257
# eval mol 258
# eval mol 259
# eval mol 260
# eval mol 261
# eval mol 262
# eval mol 263
# eval mol 264
# eval mol 265
# eval mol 266
# eval mol 267
# eval mol 268
# eval mol 269
# eval mol 270
# eval mol 271
# eval mol 272
# eval mol 273
# eval mol 274
# eval mol 275
# eval mol 276
# eval mol 277
# eval mol 278
# eval mol 279
# eval mol 280
# eval mol 281
# eval mol 282
# eval mol 283
# eval mol 284
# eval mol 285
# eval mol 286
# eval mol 287
# eval mol 288
# eval mol 289
# eval mol 290
# eval mol 291
# eval mol 292
# eval mol 293
# eval mol 294
# eval mol 295
# eval mol 296
# eval mol 297
# eval mol 298
# eval mol 299
# eval mol 300
# eval mol 301
# eval mol 302
# eval mol 303
# eval mol 304
# eval mol 305
# eval mol 306
# eval mol 307
# eval mol 308
# eval mol 309
# eval mol 310
# eval mol 311
# eval mol 312
# eval mol 313
# eval mol 314
# eval mol 315
# eval mol 316
# eval mol 317
# eval mol 318
# eval mol 319
# eval mol 320
# eval mol 321
# eval mol 322
# eval mol 323
# eval mol 324
# eval mol 325
# eval mol 326
# eval mol 327
# eval mol 328
# eval mol 329
# eval mol 330
# eval mol 331
# eval mol 332
# eval mol 333
# eval mol 334
# eval mol 335
# eval mol 336
# eval mol 337
# eval mol 338
# eval mol 339
# eval mol 340
# eval mol 341
# eval mol 342
# eval mol 343
# eval mol 344
# eval mol 345
# eval mol 346
# eval mol 347
# eval mol 348
# eval mol 349
# eval mol 350
# eval mol 351
# eval mol 352
# eval mol 353
# eval mol 354
# eval mol 355
# eval mol 356
# eval mol 357
# eval mol 358
# eval mol 359
# eval mol 360
# eval mol 361
# eval mol 362
# eval mol 363
# eval mol 364
# eval mol 365
# eval mol 366
# eval mol 367
# eval mol 368
# eval mol 369
# eval mol 370
# eval mol 371
# eval mol 372
# eval mol 373
# eval mol 374
# eval mol 375
# eval mol 376
# eval mol 377
# eval mol 378
# eval mol 379
# eval mol 380
# eval mol 381
# eval mol 382
# eval mol 383
# eval mol 384
# eval mol 385
# eval mol 386
# eval mol 387
# eval mol 388
# eval mol 389
# eval mol 390
# eval mol 391
# eval mol 392
# eval mol 393
# eval mol 394
# eval mol 395
# eval mol 396
# eval mol 397
# eval mol 398
# eval mol 399
# eval mol 400
# eval mol 401
# eval mol 402
# eval mol 403
# eval mol 404
# eval mol 405
# eval mol 406
# eval mol 407
# eval mol 408
# eval mol 409
# eval mol 410
# eval mol 411
# eval mol 412
# eval mol 413
# eval mol 414
# eval mol 415
# eval mol 416
# eval mol 417
# eval mol 418
# eval mol 419
# eval mol 420
# eval mol 421
# eval mol 422
# eval mol 423
# eval mol 424
# eval mol 425
# eval mol 426
# eval mol 427
# eval mol 428
# eval mol 429
# eval mol 430
# eval mol 431
# eval mol 432
# eval mol 433
# eval mol 434
# eval mol 435
# eval mol 436
# eval mol 437
# eval mol 438
# eval mol 439
# eval mol 440
# eval mol 441
# eval mol 442
# eval mol 443
# eval mol 444
# eval mol 445
# eval mol 446
# eval mol 447
# eval mol 448
# eval mol 449
# eval mol 450
# eval mol 451
# eval mol 452
# eval mol 453
# eval mol 454
# eval mol 455
# eval mol 456
# eval mol 457
# eval mol 458
# eval mol 459
# eval mol 460
# eval mol 461
# eval mol 462
# eval mol 463
# eval mol 464
# eval mol 465
# eval mol 466
# eval mol 467
# eval mol 468
# eval mol 469
# eval mol 470
# eval mol 471
# eval mol 472
# eval mol 473
# eval mol 474
# eval mol 475
# eval mol 476
# eval mol 477
# eval mol 478
# eval mol 479
# eval mol 480
# eval mol 481
# eval mol 482
# eval mol 483
# eval mol 484
# eval mol 485
# eval mol 486
# eval mol 487
# eval mol 488
# eval mol 489
# eval mol 490
# eval mol 491
# eval mol 492
# eval mol 493
# eval mol 494
# eval mol 495
# eval mol 496
# eval mol 497
# eval mol 498
# eval mol 499

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
m = np.array(top_500_similar_mat)
plt.imshow(m, interpolation='nearest', cmap='plasma')
plt.colorbar()
plt.show()

# %%
m = np.array(top_500_surprise_mat)
plt.imshow(m, interpolation='nearest', cmap='plasma')
plt.colorbar()
plt.show()

# %%
fig7, ax7 = plt.subplots()
ax7.set_title('Best SuCOS scores for similar and surprise sets')
ax7.boxplot([list(best_sucos_similar['best_sucos']), list(best_sucos_surprise['best_sucos'])])

plt.show()

# %%
fig7, ax7 = plt.subplots()
ax7.set_title('Best Tanimoto scores for similar and surprise sets')
ax7.boxplot([list(best_tanimoto_similar['best_tanimoto']), list(best_tanimoto_surprise['best_tanimoto'])])

plt.show()

# %%
# top_250_similar_diverse, inds_250sd = mols_from_morgan(top_500_similar_mols, 250)  
df250 = best_sucos_similar.iloc[:250]

# %%
df250.sort_values(by=['best_sucos'], ascending=False)
# Out:
#                  candidate_name               candidate_smiles  \
# 730   GDP_frag2-similar-rsn_566      CNC(=S)N1CCOC(C(F)(F)F)C1
# 1364  GDP_frag2-similar-rsn_610  CNC(=S)N1CC(CO)OC(C(F)(F)F)C1
# 843   GDP_frag2-similar-rsn_729            CNC(=S)N1CCOC(CO)C1
# 207   GDP_frag2-similar-rsn_206                      OC1COCC1F
# 402   GDP_frag2-similar-rsn_784                      OC1COCC1O
# 169   GDP_frag2-similar-rsn_550               COCC1C[NH2+]CCO1
# 850   GDP_frag2-similar-rsn_430              CNC(=S)NC1COCC1OC
# 786   GDP_frag2-similar-rsn_163                      COCC(O)CO
# 671   GDP_frag2-similar-rsn_362         CNC(=S)N1CCC(CO)(OC)C1
# 48    GDP_frag2-similar-rsn_365            CNC(=S)N1CCOCC(O)C1
# 380   GDP_frag2-similar-rsn_919                       COCC1CO1
# 290   GDP_frag2-similar-rsn_107                   [NH3+]C1COC1
# 257   GDP_frag2-similar-rsn_982                     OCC1COCCO1
# 620   GDP_frag2-similar-rsn_563                C[NH2+]C1COCC1O
# 1315  GDP_frag2-similar-rsn_869                      COC(CO)CO
# 1430  GDP_frag2-similar-rsn_125              C[NH+](C)C1COCC1O
# 692   GDP_frag2-similar-rsn_932             CNC(=S)N(C)C1CCOC1
# 779   GDP_frag2-similar-rsn_753                 OCC1(CO)COCCO1
# 845   GDP_frag2-similar-rsn_964                        OCC1CO1
# 2     GDP_frag2-similar-rsn_664            CNC(=O)N1CCOC(OC)C1
# 5     GDP_frag2-similar-rsn_303                   [NH3+]CCOCCO
# 1597  GDP_frag2-similar-rsn_942          CNC(=S)N1CC(O)C(CO)C1
# 1779  GDP_frag2-similar-rsn_144           COC1(CO)CN(C(N)=O)C1
# 89    GDP_frag2-similar-rsn_599                OCC1C[NH2+]CCO1
# 1596  GDP_frag2-similar-rsn_458         CNC(=S)N1CCOC(C(C)O)C1
# 1587  GDP_frag2-similar-rsn_226            CNC(=O)N(C)C1COCC1O
# 740   GDP_frag2-similar-rsn_631                 [NH3+]C1COCC1O
# 1642  GDP_frag2-similar-rsn_469              COC1OC(CO)C(O)C1O
# 647   GDP_frag2-similar-rsn_860            OCC(O)C1C[NH2+]CCO1
# 162    GDP_frag2-similar-rsn_17             COCC(O)(C[NH3+])CO
# ...                         ...                            ...
# 1826  GDP_frag2-similar-rsn_674      [NH3+]C1C(O)OC(CO)C(O)C1O
# 67     GDP_frag2-similar-rsn_40                    ClCC1COCCO1
# 1611  GDP_frag2-similar-rsn_159         CC(=O)N1CCOC(C(O)CO)C1
# 512   GDP_frag2-similar-rsn_865           CNC(=S)NCC1CC(CO)CO1
# 418    GDP_frag2-similar-rsn_58            COCC1CC(O)CN1C(N)=O
# 1060  GDP_frag2-similar-rsn_276               N/C(CCO)=N/OCCCO
# 733   GDP_frag2-similar-rsn_832            [NH3+]C(CO)CC1CCCO1
# 520   GDP_frag2-similar-rsn_981                NC(=O)NC1COCC1O
# 882    GDP_frag2-similar-rsn_25             COC1(C[NH3+])CCOC1
# 1136  GDP_frag2-similar-rsn_971               [NH3+]CCC1COCC1O
# 828   GDP_frag2-similar-rsn_334             CC([NH3+])C1COCCO1
# 209    GDP_frag2-similar-rsn_45            OC1CC(OCC(F)(F)F)C1
# 1514  GDP_frag2-similar-rsn_368             CC1(C[NH3+])COCCO1
# 875   GDP_frag2-similar-rsn_836               OCC1CC[NH2+]CCO1
# 1748   GDP_frag2-similar-rsn_98            [NH3+]CC1(CCO)CCOC1
# 453   GDP_frag2-similar-rsn_760            CC(=O)N1CCOCC(CO)C1
# 1886  GDP_frag2-similar-rsn_972                CC(=O)NC1COCC1O
# 1660  GDP_frag2-similar-rsn_190            NC(=O)NCC1CC(CO)CO1
# 1272  GDP_frag2-similar-rsn_975                    C1CC2OC2CO1
# 1655  GDP_frag2-similar-rsn_323            CC1OCCC1(O)CNC(N)=O
# 226     GDP_frag2-similar-rsn_1             COCCC(C)(O)C[NH3+]
# 1270  GDP_frag2-similar-rsn_841            COCC1(C[NH3+])CCCO1
# 609   GDP_frag2-similar-rsn_457                  OCC1OC(O)CC1O
# 519   GDP_frag2-similar-rsn_301            NC(=O)NCC1CC(O)CCO1
# 1820  GDP_frag2-similar-rsn_790             [NH3+]CCC1(O)CCOC1
# 1829  GDP_frag2-similar-rsn_489             CC(C)(C[NH3+])OCCO
# 255   GDP_frag2-similar-rsn_302                COCC(O)CC[NH3+]
# 704    GDP_frag2-similar-rsn_97               CC(=O)NCC1COCC1O
# 501   GDP_frag2-similar-rsn_261                   N#CC1COCCC1O
# 111   GDP_frag2-similar-rsn_678                 N#CCC1(CO)COC1
#
#                               candidate_conformers_file initial_hit  \
# 730   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 1364  /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 843   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 207   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 402   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 169   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 850   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 786   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 671   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 48    /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 380   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 290   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 257   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 620   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 1315  /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 1430  /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 692   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 779   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 845   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 2     /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 5     /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 1597  /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 1779  /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 89    /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 1596  /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 1587  /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 740   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 1642  /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 647   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 162   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# ...                                                 ...         ...
# 1826  /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 67    /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 1611  /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 512   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 418   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 1060  /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 733   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 520   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 882   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 1136  /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 828   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 209   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 1514  /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 875   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 1748  /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 453   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 1886  /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 1660  /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 1272  /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 1655  /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 226   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 1270  /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 609   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 519   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 1820  /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 1829  /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 255   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 704   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 501   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
# 111   /data/GDP_frags/GDP_frag2/GDP_frag2-similar-rs...     GDP.sdf
#
#       best_sucos  best_sucos_id  best_tanimoto  best_tanimoto_id
# 730     0.662476             83       0.566098                12
# 1364    0.650553             61       0.523268                13
# 843     0.629860             56       0.567248                74
# 207     0.628993             44       0.733401                44
# 402     0.628912             53       0.734927                53
# 169     0.616389             23       0.659960                88
# 850     0.604582             64       0.559946                23
# 786     0.599886             25       0.714918                29
# 671     0.599144             55       0.524893                48
# 48      0.598655             62       0.578967                47
# 380     0.590238             98       0.747719                74
# 290     0.589587             81       0.786950                55
# 257     0.584836             86       0.710085                54
# 620     0.578713             13       0.685487                82
# 1315    0.576678             58       0.735217                17
# 1430    0.570474             66       0.658115                66
# 692     0.570200             64       0.576350                17
# 779     0.569234             61       0.667978                67
# 845     0.567953             28       0.790804                58
# 2       0.566216             97       0.579103                51
# 5       0.562055             56       0.702870                94
# 1597    0.559377             29       0.552311                12
# 1779    0.556364             92       0.609464                85
# 89      0.553181             18       0.707116                46
# 1596    0.552894             11       0.557436                89
# 1587    0.551590             75       0.555569                80
# 740     0.545734             73       0.730502                73
# 1642    0.545634             80       0.615433                80
# 647     0.543538             79       0.642866                55
# 162     0.543397             79       0.662035                79
# ...          ...            ...            ...               ...
# 1826    0.457943             11       0.633539                75
# 67      0.457833             58       0.689612                68
# 1611    0.457474             38       0.581698                25
# 512     0.457334             15       0.543277                66
# 418     0.457207             56       0.621528                85
# 1060    0.457010              0       0.598285                63
# 733     0.456203             55       0.624098                15
# 520     0.455763             93       0.627151                73
# 882     0.455762             60       0.686834                29
# 1136    0.455758             82       0.646503                13
# 828     0.455722              9       0.672407                31
# 209     0.455436              2       0.613524                19
# 1514    0.455359             20       0.677121                23
# 875     0.454865             15       0.688313                 8
# 1748    0.454173             64       0.654548                76
# 453     0.453872             99       0.617235                98
# 1886    0.453270             53       0.619396                70
# 1660    0.453102             99       0.589362                72
# 1272    0.452519             47       0.748557                74
# 1655    0.452163             60       0.609709                84
# 226     0.451955             38       0.651701                19
# 1270    0.451703             91       0.644080                42
# 609     0.451592             81       0.669448                50
# 519     0.451306             12       0.586237                 3
# 1820    0.450758             28       0.675084                19
# 1829    0.450598             69       0.687477                81
# 255     0.450080             91       0.669432                17
# 704     0.449224             38       0.617055                88
# 501     0.449075             57       0.681007                 5
# 111     0.448993             63       0.677451                91
#
# [250 rows x 8 columns]

# %%
df = df250.sort_values(by=['best_sucos'], ascending=False)

df250_mols = mols_from_df(df)
# top_250_similar_diverse_mat = compare_mols_sucos(df250_mols)

# %%
# m = np.array(top_250_similar_diverse_mat)
# plt.imshow(m, interpolation='nearest', cmap='plasma')
# plt.colorbar()
# plt.show()

# %%
# nl = []
# for l in top_500_similar_mat[:250]:
#     nl.append(l[:250])
# m = np.array(nl)
# plt.imshow(m, interpolation='nearest', cmap='plasma')
# plt.colorbar()
# plt.show()

# %%
# fig7, ax7 = plt.subplots()
# ax7.set_title('Best SuCOS scores for similar_diverse_250 and similar_500')
# ax7.boxplot([list(df['best_sucos']), list(best_sucos_similar['best_sucos'])])

# plt.show()

# %%
best_sucos_surprise.iloc[:250].to_csv('/data/GDP_frags/GDP_frag2/250_surprise_sucos.csv')

# %%
df.to_csv('/data/GDP_frags/GDP_frag2/250_similar_sucos_diverse.csv')

# %%
writer = Chem.SDWriter('/data/GDP_frags/GDP_frag2/250_similar_sucos_diverse.sdf')
for mol in df250_mols:
    writer.write(mol)

# %%
writer = Chem.SDWriter('/data/GDP_frags/GDP_frag2/250_surprise_sucos.sdf')
for mol in top_500_surprise_mols[:250]:
    writer.write(mol)
