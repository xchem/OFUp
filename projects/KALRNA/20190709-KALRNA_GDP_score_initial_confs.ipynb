# %% [markdown]
# # KALRNA: Scoring initial poses

# %% [markdown]
# ## 1. Scoring 3D aligned structures (fragment-based approach)
# To evaluate the quality of the alignments produced (see 20190626-KALRNA_genetate_initial_confs), two scores were used to compare the aligned conformations for each follow-up candidate to their respective hit molecule:
# - SuCOS score: The SuCOS score is an open-source shape and chemical feature overlap metric
# - Tanimoto shape similarity: This score compares the similarity in shape between two molecules
#
# The best conformation for each score is taken as the best initial geometry guess for each candidate molecule.
#
# The results, indicating the best conformation for each candidate molecule for both the 'surprise' and 'similar' sets are returned as a dictionary, which can be displayed and manipulated by pandas. The dictionary gives the best score for each of the two scores described, the conformer-containing sdf file, and the index of the molecule in the sdf file for both scores, so that the conformations can be easily accessed from the original aligned conformer sdf file
#
# ### Code (adapted from https://bitbucket.org/Susanhleung/sucos/src/master/calc_SuCOS.py):

# %%
import argparse, os, gzip
import glob
import operator
import numpy as np
import rdkit
from rdkit import Chem
from rdkit.Chem import AllChem, rdShapeHelpers
from rdkit.Chem.FeatMaps import FeatMaps
from rdkit import RDConfig
from rdkit.Chem import Draw
from joblib import Parallel, delayed
import multiprocessing

fdef = AllChem.BuildFeatureFactory(os.path.join(RDConfig.RDDataDir, 'BaseFeatures.fdef'))

fmParams = {}
for k in fdef.GetFeatureFamilies():
    fparams = FeatMaps.FeatMapParams()
    fmParams[k] = fparams

keep = ('Donor', 'Acceptor', 'NegIonizable', 'PosIonizable', 'ZnBinder',
        'Aromatic', 'Hydrophobe', 'LumpedHydrophobe')

def get_FeatureMapScore(small_m, large_m, score_mode=FeatMaps.FeatMapScoreMode.All):
    featLists = []
    for m in [small_m, large_m]:
        rawFeats = fdef.GetFeaturesForMol(m)
        # filter that list down to only include the ones we're intereted in
        featLists.append([f for f in rawFeats if f.GetFamily() in keep])
    fms = [FeatMaps.FeatMap(feats=x, weights=[1] * len(x), params=fmParams) for x in featLists]
    fms[0].scoreMode = score_mode
    fm_score = fms[0].ScoreFeats(featLists[1]) / min(fms[0].GetNumFeatures(), len(featLists[1]))
    return fm_score

def sucos_mol_to_mol(mol1, mol2, score_mode=FeatMaps.FeatMapScoreMode.All):
    ref = Chem.AddHs(mol1)
    prb = Chem.AddHs(mol2)
    
    fm_score = get_FeatureMapScore(ref, prb, score_mode)
    fm_score = np.clip(fm_score, 0, 1)

    protrude_dist = rdShapeHelpers.ShapeProtrudeDist(ref, prb,
            allowReordering=False)
    protrude_dist = np.clip(protrude_dist, 0, 1)

    SuCOS_score = 0.5*fm_score + 0.5*(1 - protrude_dist)
    
    return SuCOS_score


def score(ref_file, prb_file, score_mode=FeatMaps.FeatMapScoreMode.All, p=False):
    reflig = Chem.MolFromMolFile(ref_file, sanitize=True)
    ref = Chem.AddHs(reflig)
    prb_mols = Chem.SDMolSupplier(prb_file, sanitize=True)
    prb_mols = [x for x in prb_mols if x]
    idx = 0
    
    results_sucos = {}
    results_tani = {}
    
    smi_mol = Chem.MolToSmiles(prb_mols[0])
    
    for prb_mol in prb_mols:
        
        prb = Chem.AddHs(prb_mol)
                
        fm_score = get_FeatureMapScore(ref, prb, score_mode)
        fm_score = np.clip(fm_score, 0, 1)
        
        protrude_dist = rdShapeHelpers.ShapeProtrudeDist(ref, prb,
                allowReordering=False)
        protrude_dist = np.clip(protrude_dist, 0, 1)
        
        SuCOS_score = 0.5*fm_score + 0.5*(1 - protrude_dist)
        tanimoto_score = Chem.rdShapeHelpers.ShapeTanimotoDist(ref, prb)
        
        results_sucos[str(idx)] = SuCOS_score
        results_tani[str(idx)] = tanimoto_score
        
        if p:
        
            print ("********************************")
            print ("index: " + str(idx))
            print ("SuCOS score:\t%f" % SuCOS_score)
            print ("Tani score:\t%f" % tanimoto_score)
            print ("********************************")
        
        idx+=1

    return results_sucos, results_tani, smi_mol, prb_mols, reflig


def select_highest(results, number):
    ids = []
    r = results
    while len(ids)<number:
        i = max(results.items(), key=operator.itemgetter(1))[0]
        ids.append(int(i))
        r.pop(i, None)
    return ids

def select_lowest(results, number):
    ids = []
    r = results
    while len(ids)<number:
        i = min(results.items(), key=operator.itemgetter(1))[0]
        ids.append(int(i))
        r.pop(i, None)
    return ids

def score_all_confs(hit_file_directory, initial_hit, all_confs_paths):

    all_results_dict = {
        'candidate_name': [],
        'candidate_smiles': [],
        'candidate_conformers_file': [],
        'initial_hit': [],
        'best_sucos': [],
        'best_sucos_id': [],
        'best_tanimoto': [],
        'best_tanimoto_id': [],
    }
    
    for i in range(0, len(all_confs_paths)):
        results_sucos, results_tani, smiles, prb_mols, reflig = score(ref_file=initial_hit, prb_file=all_confs_paths[i])
        print('running ' + str(i) + '/' + str(len(all_confs_paths)))
        # best sucos socre and id
        r = results_sucos.copy()
        idx = select_highest(r, 1)[0]
        sucos_score = results_sucos[str(idx)]
        # best tanimoto socre and id
        s = results_tani.copy()
        idy = select_lowest(s, 1)[0]
        tani_score = results_tani[str(idy)]

        all_results_dict['candidate_name'].append(all_confs_paths[i].split('/')[-1].replace('_confs_aligned.sdf', ''))
        all_results_dict['candidate_smiles'].append(smiles)
        all_results_dict['candidate_conformers_file'].append(all_confs_paths[i])
        all_results_dict['initial_hit'].append(initial_hit.split('/')[-1])
        all_results_dict['best_sucos'].append(sucos_score)
        all_results_dict['best_sucos_id'].append(idx)
        all_results_dict['best_tanimoto'].append(tani_score)
        all_results_dict['best_tanimoto_id'].append(idy)

    return all_results_dict

# %%
hit_file_directory = '/Users/res3/michellab/XChem-examples/KALRNA/GDP_frags/GDP/'
initial_hit = '/Users/res3/michellab/XChem-examples/KALRNA/GDP_frags/GDP/GDP.sdf'
all_confs_paths = glob.glob(str(hit_file_directory + '*_confs_aligned.sdf'))

all_results_dict = score_all_confs(hit_file_directory=hit_file_directory, 
                                   initial_hit=initial_hit, 
                                   all_confs_paths=all_confs_paths)
# Out:
# running 0/1000
# running 1/1000
# running 2/1000
# running 3/1000
# running 4/1000
# running 5/1000
# running 6/1000
# running 7/1000
# running 8/1000
# running 9/1000
# running 10/1000
# running 11/1000
# running 12/1000
# running 13/1000
# running 14/1000
# running 15/1000
# running 16/1000
# running 17/1000
# running 18/1000
# running 19/1000
# running 20/1000
# running 21/1000
# running 22/1000
# running 23/1000
# running 24/1000
# running 25/1000
# running 26/1000
# running 27/1000
# running 28/1000
# running 29/1000
# running 30/1000
# running 31/1000
# running 32/1000
# running 33/1000
# running 34/1000
# running 35/1000
# We can also see that the majority of the top ranked compounds are from the 'similar' set - which is to be expected. To add some diversity to the molecules that will be investigated further, the two sets have been separated back out for analysis (and the results saved out as csv files so we can look again later).

# %%
import pandas as pd
# create dataframe from results of scoring alignments
df = pd.DataFrame.from_dict(all_results_dict)

# top 500 compounds from each search set(similar/surprise) and score(sucos/tanimoto)
best_sucos_similar = df[df['candidate_name'].str.contains("similar")].sort_values(by=['best_sucos'], ascending=False).head(500)
best_tanimoto_similar = df[df['candidate_name'].str.contains("similar")].sort_values(by=['best_tanimoto'], ascending=True).head(500)
# best_sucos_surprise = df[df['candidate_name'].str.contains("surprise")].sort_values(by=['best_sucos'], ascending=False).head(500)
# best_tanimoto_surprise = df[df['candidate_name'].str.contains("surprise")].sort_values(by=['best_tanimoto'], ascending=True).head(500)

# save the top 500 as csv files
# best_sucos_similar.to_csv('/Users/res3/michellab/XChem-examples/KALRNA/GDP_frags/GDP/500_similar_sucos.csv')
# best_tanimoto_similar.to_csv('/Users/res3/michellab/XChem-examples/KALRNA/GDP_frags/GDP/500_similar_tanimoto.csv')
# #best_sucos_surprise.to_csv('/Users/res3/michellab/XChem-examples/KALRNA/GDP_frags/GDP/500_surprise_sucos.csv')
# #best_tanimoto_surprise.to_csv('/Users/res3/michellab/XChem-examples/KALRNA/GDP_frags/GDP/500_surprise_tanimoto.csv')

# display results frame
df.sort_values(by=['best_sucos'], ascending=False)
# Out:
#           candidate_name                                   candidate_smiles  \
# 639  GDP-similar-rsn_349  CN(CC1COCCN1C(=O)c1nc(N)cc(=O)[nH]1)C(=O)CN(C)...
# 869  GDP-similar-rsn_457             Nc1nc2c(ncn2C2OC(CO)C(O)C2O)c(=O)[nH]1
# 768  GDP-similar-rsn_719  CN(C)S(=O)(=O)N(C)CC(=O)NCC1COCCN1C(=O)c1nc(N)...
# 871  GDP-similar-rsn_419  CN(C)S(=O)(=O)N(C)CC(=O)NC1COCCN(C(=O)c2nc(Cl)...
# 364  GDP-similar-rsn_810     COCCOCC(=O)NCC1COCCN1C(=O)c1nc(Cl)c(=O)[nH]c1N
# 343  GDP-similar-rsn_416  CNS(=O)(=O)NCC(=O)NCC1COCCN1C(=O)c1nc(Cl)c(=O)...
# 40    GDP-similar-rsn_10  CN(C)S(=O)(=O)CC(=O)NCC1CN(C(=O)c2nc(Cl)c(=O)[...
# 497  GDP-similar-rsn_925  CN(CC(=O)NCC1COCCN1C(=O)c1nc(Cl)c(=O)[nH]c1N)S...
# 468  GDP-similar-rsn_911  CCS(=O)(=O)N(C)CC(=O)NCC1COCCN1C(=O)c1nc(N)cc(...
# 723  GDP-similar-rsn_149  CS(C)(=O)=NS(=O)(=O)N1CCN(C(=O)Cn2cnc3c(=O)[nH...
# 351   GDP-similar-rsn_17  CN(CC1COCCN1C(=O)c1nc(N)cc(=O)[nH]1)C(=O)C(C)(...
# 619   GDP-similar-rsn_84   CC(C)C(=O)Nc1nc2c(ncn2C2OC(CO)C(O)C2O)c(=O)[nH]1
# 208  GDP-similar-rsn_624  CN(CC1COCCN1C(=O)c1nc(N)cc(=O)[nH]1)C(=O)CCS(=...
# 828  GDP-similar-rsn_531                 CC(=O)OCCOCn1cnc2c(=O)[nH]c(N)nc21
# 294  GDP-similar-rsn_744  COCC(OC)C(=O)N(C)CC1COCCN1C(=O)c1nc(N)cc(=O)[nH]1
# 523  GDP-similar-rsn_254  CN(CC1CN(C(=O)c2nc(Cl)c(=O)[nH]c2N)CCO1)C(=O)C...
# 245  GDP-similar-rsn_927  CN(C)S(=O)(=O)CC(=O)NCC1COCCN1C(=O)c1nc(N)cc(=...
# 632  GDP-similar-rsn_863  CNS(=O)(=O)CC(=O)N(C)CC1COCCN1C(=O)c1nc(N)cc(=...
# 667  GDP-similar-rsn_654  CNS(=O)(=O)CCC(=O)NCCOC1CN(C(=O)c2nc(Cl)c(=O)[...
# 607  GDP-similar-rsn_680     COCC(OC)C(=O)NCC1COCCN1C(=O)c1nc(N)cc(=O)[nH]1
# 549  GDP-similar-rsn_436  CNS(=O)(=O)NCC(=O)N(C)CC1COCCN1C(=O)c1nc(N)cc(...
# 956  GDP-similar-rsn_518  COCC(C)(O)C(=O)NCC1CN(C(=O)c2nc(Cl)c(=O)[nH]c2...
# 818  GDP-similar-rsn_528  CN(CC(=O)NCC1COCCN1C(=O)c1nc(N)cc(=O)[nH]1)S(C...
# 72   GDP-similar-rsn_974  CC(C(=O)N(C)CC1COCCN1C(=O)c1nc(N)cc(=O)[nH]1)S...
# 771  GDP-similar-rsn_466    Nc1nc(F)nc2c1ncn2C1OC(COP(=O)([O-])[O-])C(O)C1O
# 484  GDP-similar-rsn_313  CN(C)S(=O)(=O)N(C)CC(=O)NCC1COCCN1C(=O)c1nc(Cl...
# 502   GDP-similar-rsn_70  CN(CC1COCCN1C(=O)c1nc(N)cc(=O)[nH]1)C(=O)CS(=O...
# 441  GDP-similar-rsn_423   COC(C)C(O)C(=O)NCC1COCCN1C(=O)c1nc(N)cc(=O)[nH]1
# 369  GDP-similar-rsn_924  CN(C)S(=O)(=O)NCC(=O)NCCOC1CN(C(=O)c2nc(Cl)c(=...
# 977  GDP-similar-rsn_729  CCOC[C@H](N=[N+]=[N-])C(=O)N(C)C[C@H]1CN(C(=O)...
# ..                   ...                                                ...
# 82   GDP-similar-rsn_572                       Nc1ncnc2c1ncn2C1CC(O)C(CO)O1
# 919  GDP-similar-rsn_885       COC(=O)C(C)ONC(=O)C1CCC(Cn2cnc3c(N)ncnc32)O1
# 503  GDP-similar-rsn_726         COC(=O)CCCC(=O)N1CC(n2cnc3c(N)nc(N)nc32)C1
# 614  GDP-similar-rsn_379   CNS(=O)(=O)NCCCNC(=O)CCc1c(C)nc2c(C(N)=O)cnn2c1C
# 48   GDP-similar-rsn_209  COC(=O)C1(CNC(=O)C2CCC(Cn3cnc4c(N)ncnc43)O2)CC...
# 627  GDP-similar-rsn_265  CC(CN(C)C(=O)C1CCC(Cn2cnc3c(N)ncnc32)O1)C(=O)O...
# 0    GDP-similar-rsn_511          CC(C)OCCONC(=O)C1CCC(Cn2cnc3c(N)ncnc32)O1
# 767  GDP-similar-rsn_129     COCCOCCOCC(O)CNC(=O)C1CCC(Cn2cnc3c(N)ncnc32)O1
# 539  GDP-similar-rsn_655    COCCS(=O)(=O)CC(=O)NCCOCCn1cc(-c2cccc(CO)n2)nn1
# 699  GDP-similar-rsn_448   COC(=O)CC(C)(C)CC(=O)N1CC(n2cnc3c(N)nc(N)nc32)C1
# 45   GDP-similar-rsn_945    Cc1nc2c(C(N)=O)cnn2c(C)c1CCC(=O)NCCCNS(C)(=O)=O
# 906  GDP-similar-rsn_553  Cc1nc2c(C(N)=O)cnn2c(C)c1CCC(=O)N1CC(CS(=O)(=O...
# 878   GDP-similar-rsn_56  CC(C)(C)OC(=O)NOCC(=O)N1CC(n2cnc3c(N)nc(N)nc32)C1
# 379  GDP-similar-rsn_322  CN(C)S(=O)(=O)CC(=O)N1CCOC(Cn2cc(COc3cccc(CO)c...
# 775  GDP-similar-rsn_218  CN(C)[S@@](C)(=O)=NC(=O)Cn1cc(Cn2cnc3c(N)ncnc3...
# 471   GDP-similar-rsn_44  COCCS(=O)(=O)CC(=O)N1CCOC(Cn2cc(-c3ccc(CO)cc3)...
# 273  GDP-similar-rsn_271                 COCCOCCONC(=O)CCCCn1cnc2c(N)ncnc21
# 548  GDP-similar-rsn_151  CC(C)(C)S(=O)(=O)CC(=O)N1CCOC(Cn2cc(-c3ccc(CO)...
# 289  GDP-similar-rsn_947               Nc1ncnc2c1ncn2CC1CCC(C(=O)NCCOCCO)O1
# 974  GDP-similar-rsn_880               Cc1nn(C2CCS(=O)(=O)C2)c2ncc(C=O)cc12
# 552  GDP-similar-rsn_478  Cc1nc2c(C(N)=O)cnn2c(C)c1CCC(=O)N1CCC12CS(=O)(...
# 938  GDP-similar-rsn_833             O=c1[nH]c(CO)nc2sc3c(c12)CCS(=O)(=O)C3
# 916  GDP-similar-rsn_435  Cc1c(-c2nc(CCN(C(C)C)S(C)(=O)=O)no2)cnn1-c1ccc...
# 725  GDP-similar-rsn_107             CCOCCONC(=O)C1CCC(Cn2cnc3c(N)ncnc32)O1
# 988   GDP-similar-rsn_87               Cc1nn(C2CCOCC2)c2ncc(S(N)(=O)=O)cc12
# 862  GDP-similar-rsn_353                  Nc1ncnc2c1ncn2CC1CCC(C(=O)[O-])O1
# 392  GDP-similar-rsn_216                   NC(=O)C1CCC(Cn2cnc3c(N)ncnc32)O1
# 93   GDP-similar-rsn_408                      NC(=O)c1cnn2c3c(cnc12)CCOC3=O
# 688  GDP-similar-rsn_798                          Clc1ncnc2nc(N3CCOCC3)sc12
# 827  GDP-similar-rsn_666              Cc1nc2sc3c(c2c(=O)[nH]1)CCS(=O)(=O)C3
#
#                              candidate_conformers_file initial_hit  \
# 639  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 869  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 768  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 871  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 364  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 343  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 40   /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 497  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 468  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 723  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 351  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 619  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 208  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 828  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 294  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 523  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 245  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 632  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 667  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 607  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 549  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 956  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 818  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 72   /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 771  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 484  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 502  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 441  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 369  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 977  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# ..                                                 ...         ...
# 82   /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 919  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 503  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 614  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 48   /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 627  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 0    /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 767  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 539  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 699  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 45   /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 906  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 878  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 379  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 775  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 471  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 273  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 548  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 289  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 974  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 552  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 938  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 916  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 725  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 988  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 862  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 392  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 93   /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 688  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 827  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
#
#      best_sucos  best_sucos_id  best_tanimoto  best_tanimoto_id
# 639    0.582254             82       0.390176                82
# 869    0.566026             26       0.376557                26
# 768    0.563893             59       0.389107                41
# 871    0.562815             77       0.419145                56
# 364    0.561870             68       0.429469                69
# 343    0.559714             71       0.412684                71
# 40     0.550521             56       0.408001                85
# 497    0.549861             86       0.363360                45
# 468    0.548418             78       0.349908                16
# 723    0.548386             32       0.439853                33
# 351    0.546688             16       0.348763                16
# 619    0.546565             14       0.481050                14
# 208    0.545264             11       0.409310                11
# 828    0.543781              5       0.415913                 5
# 294    0.542875              9       0.383005                95
# 523    0.542738             36       0.415572                 6
# 245    0.541116             60       0.408040                 0
# 632    0.540342              8       0.364957                48
# 667    0.540133             13       0.451760                21
# 607    0.539474             18       0.380957                86
# 549    0.538159             11       0.420439                11
# 956    0.537299             43       0.401176                72
# 818    0.536982             71       0.321554                15
# 72     0.536904              7       0.358732                41
# 771    0.536746             42       0.380814                87
# 484    0.536588             53       0.432062                 4
# 502    0.536437             57       0.403907                72
# 441    0.536354             97       0.344627                55
# 369    0.536282             26       0.460810                26
# 977    0.535745             49       0.438210                 9
# ..          ...            ...            ...               ...
# 82     0.394969             15       0.469625                36
# 919    0.394744             92       0.454610                86
# 503    0.394458             74       0.428783                71
# 614    0.394449             17       0.478985                70
# 48     0.393830             84       0.488245                90
# 627    0.392717             48       0.491219                55
# 0      0.392506             56       0.436654                56
# 767    0.391340             80       0.526992                81
# 539    0.390914             53       0.525640                56
# 699    0.390828             39       0.433071                27
# 45     0.390301             22       0.517836                39
# 906    0.390101             98       0.498861                12
# 878    0.389514             66       0.485555                66
# 379    0.389270             61       0.506216                14
# 775    0.389020             67       0.473550                66
# 471    0.388727             39       0.509424                71
# 273    0.387979             28       0.497210                97
# 548    0.387910             15       0.469073                15
# 289    0.387878              3       0.432947                 3
# 974    0.387875             58       0.499441                43
# 552    0.386258             83       0.473842                59
# 938    0.385844             82       0.522043                51
# 916    0.382517             26       0.527877                89
# 725    0.382249             82       0.492147                82
# 988    0.381451             48       0.442480                69
# 862    0.376641             83       0.483498                83
# 392    0.375309             70       0.497462                67
# 93     0.366235             83       0.553590                37
# 688    0.359816             73       0.503474                22
# 827    0.352879              7       0.538531                39
#
# [1000 rows x 8 columns]

# %% [markdown]
# ### 1.2 Evaluating the diversity of the top-scoring candidates
#
# Given the SuCos scores (and tanimoto scores) of the highest-scored compounds are extremely similar to each other (e.g. the top 14 compounds all have a SuCOS score of 0.98), it is likely that the compounds themselves are very similar to each other, and do not represent a chemically-diverse set.
#
# To evaluate this, the sucos score for each of the top 500 compounds (scored with sucos) with every other compound  for both the similar and surprise sets was calculated

# %%
from rdkit.Chem.rdMolDescriptors import GetMorganFingerprint
from rdkit import DataStructs
from rdkit.SimDivFilters.rdSimDivPickers import MaxMinPicker

def mols_from_df(df, files_col='candidate_conformers_file', id_col='best_sucos_id'):
    mols = [Chem.SDMolSupplier(f)[int(idx)] for f, idx in [(df.iloc[i][files_col], 
                                                            df.iloc[i][id_col]) 
                                                           for i in range(0, len(df))]]
    return mols

def mols_from_morgan(mols, number):
    def distij(i,j,fps=fps):
        return 1-DataStructs.DiceSimilarity(fps[i],fps[j])
    
    fps = [GetMorganFingerprint(x,3) for x in mols]
    nfps = len(fps)
    picker = MaxMinPicker()
    pickIndices = picker.LazyPick(distij,nfps,number,seed=23)
    picks = [mols[x] for x in pickIndices]
    
    return picks, pickIndices

def compare_mols_sucos(df):
    mat = []
    i = 0
    for mol1 in df:
        print('eval mol ' + str(i))
        arr = []
        for mol2 in df:
            arr.append(sucos_mol_to_mol(mol1=mol1, mol2=mol2))
        mat.append(arr)
        i += 1
    return mat

# %%
top_500_similar_mols = mols_from_df(best_sucos_similar)
top_500_similar_mat = compare_mols_sucos(top_500_similar_mols)
# Out:
# eval mol 0
# eval mol 1
# eval mol 2
# eval mol 3
# eval mol 4
# eval mol 5
# eval mol 6
# eval mol 7
# eval mol 8
# eval mol 9
# eval mol 10
# eval mol 11
# eval mol 12
# eval mol 13
# eval mol 14
# eval mol 15
# eval mol 16
# eval mol 17
# eval mol 18
# eval mol 19
# eval mol 20
# eval mol 21
# eval mol 22
# eval mol 23
# eval mol 24
# eval mol 25
# eval mol 26
# eval mol 27
# eval mol 28
# eval mol 29
# eval mol 30
# eval mol 31
# eval mol 32
# eval mol 33
# eval mol 34
# eval mol 35
# eval mol 36
# eval mol 37
# eval mol 38
# eval mol 39
# eval mol 40
# eval mol 41
# eval mol 42
# eval mol 43
# eval mol 44
# eval mol 45
# eval mol 46
# eval mol 47
# eval mol 48
# eval mol 49
# eval mol 50
# eval mol 51
# eval mol 52
# eval mol 53
# eval mol 54
# eval mol 55
# eval mol 56
# eval mol 57
# eval mol 58
# eval mol 59
# eval mol 60
# eval mol 61
# eval mol 62
# eval mol 63
# eval mol 64
# eval mol 65
# eval mol 66
# eval mol 67
# eval mol 68
# eval mol 69
# eval mol 70
# eval mol 71
# eval mol 72
# eval mol 73
# eval mol 74
# eval mol 75
# eval mol 76
# eval mol 77
# eval mol 78
# eval mol 79
# eval mol 80
# eval mol 81
# eval mol 82
# eval mol 83
# eval mol 84
# eval mol 85
# eval mol 86
# eval mol 87
# eval mol 88
# eval mol 89
# eval mol 90
# eval mol 91
# eval mol 92
# eval mol 93
# eval mol 94
# eval mol 95
# eval mol 96
# eval mol 97
# eval mol 98
# eval mol 99
# eval mol 100
# eval mol 101
# eval mol 102
# eval mol 103
# eval mol 104
# eval mol 105
# eval mol 106
# eval mol 107
# eval mol 108
# eval mol 109
# eval mol 110
# eval mol 111
# eval mol 112
# eval mol 113
# eval mol 114
# eval mol 115
# eval mol 116
# eval mol 117
# eval mol 118
# eval mol 119
# eval mol 120
# eval mol 121
# eval mol 122
# eval mol 123
# eval mol 124
# eval mol 125
# eval mol 126
# eval mol 127
# eval mol 128
# eval mol 129
# eval mol 130
# eval mol 131
# eval mol 132
# eval mol 133
# eval mol 134
# eval mol 135
# eval mol 136
# eval mol 137
# eval mol 138
# eval mol 139
# eval mol 140
# eval mol 141
# eval mol 142
# eval mol 143
# eval mol 144
# eval mol 145
# eval mol 146
# eval mol 147
# eval mol 148
# eval mol 149
# eval mol 150
# eval mol 151
# eval mol 152
# eval mol 153
# eval mol 154
# eval mol 155
# eval mol 156
# eval mol 157
# eval mol 158
# eval mol 159
# eval mol 160
# eval mol 161
# eval mol 162
# eval mol 163
# eval mol 164
# eval mol 165
# eval mol 166
# eval mol 167
# eval mol 168
# eval mol 169
# eval mol 170
# eval mol 171
# eval mol 172
# eval mol 173
# eval mol 174
# eval mol 175
# eval mol 176
# eval mol 177
# eval mol 178
# eval mol 179
# eval mol 180
# eval mol 181
# eval mol 182
# eval mol 183
# eval mol 184
# eval mol 185
# eval mol 186
# eval mol 187
# eval mol 188
# eval mol 189
# eval mol 190
# eval mol 191
# eval mol 192
# eval mol 193
# eval mol 194
# eval mol 195
# eval mol 196
# eval mol 197
# eval mol 198
# eval mol 199
# eval mol 200
# eval mol 201
# eval mol 202
# eval mol 203
# eval mol 204
# eval mol 205
# eval mol 206
# eval mol 207
# eval mol 208
# eval mol 209
# eval mol 210
# eval mol 211
# eval mol 212
# eval mol 213
# eval mol 214
# eval mol 215
# eval mol 216
# eval mol 217
# eval mol 218
# eval mol 219
# eval mol 220
# eval mol 221
# eval mol 222
# eval mol 223
# eval mol 224
# eval mol 225
# eval mol 226
# eval mol 227
# eval mol 228
# eval mol 229
# eval mol 230
# eval mol 231
# eval mol 232
# eval mol 233
# eval mol 234
# eval mol 235
# eval mol 236
# eval mol 237
# eval mol 238
# eval mol 239
# eval mol 240
# eval mol 241
# eval mol 242
# eval mol 243
# eval mol 244
# eval mol 245
# eval mol 246
# eval mol 247
# eval mol 248
# eval mol 249
# eval mol 250
# eval mol 251
# eval mol 252
# eval mol 253
# eval mol 254
# eval mol 255
# eval mol 256
# eval mol 257
# eval mol 258
# eval mol 259
# eval mol 260
# eval mol 261
# eval mol 262
# eval mol 263
# eval mol 264
# eval mol 265
# eval mol 266
# eval mol 267
# eval mol 268
# eval mol 269
# eval mol 270
# eval mol 271
# eval mol 272
# eval mol 273
# eval mol 274
# eval mol 275
# eval mol 276
# eval mol 277
# eval mol 278
# eval mol 279
# eval mol 280
# eval mol 281
# eval mol 282
# eval mol 283
# eval mol 284
# eval mol 285
# eval mol 286
# eval mol 287
# eval mol 288
# eval mol 289
# eval mol 290
# eval mol 291
# eval mol 292
# eval mol 293
# eval mol 294
# eval mol 295
# eval mol 296
# eval mol 297
# eval mol 298
# eval mol 299
# eval mol 300
# eval mol 301
# eval mol 302
# eval mol 303
# eval mol 304
# eval mol 305
# eval mol 306
# eval mol 307
# eval mol 308
# eval mol 309
# eval mol 310
# eval mol 311
# eval mol 312
# eval mol 313
# eval mol 314
# eval mol 315
# eval mol 316
# eval mol 317
# eval mol 318
# eval mol 319
# eval mol 320
# eval mol 321
# eval mol 322
# eval mol 323
# eval mol 324
# eval mol 325
# eval mol 326
# eval mol 327
# eval mol 328
# eval mol 329
# eval mol 330
# eval mol 331
# eval mol 332
# eval mol 333
# eval mol 334
# eval mol 335
# eval mol 336
# eval mol 337
# eval mol 338
# eval mol 339
# eval mol 340
# eval mol 341
# eval mol 342
# eval mol 343
# eval mol 344
# eval mol 345
# eval mol 346
# eval mol 347
# eval mol 348
# eval mol 349
# eval mol 350
# eval mol 351
# eval mol 352
# eval mol 353
# eval mol 354
# eval mol 355
# eval mol 356
# eval mol 357
# eval mol 358
# eval mol 359
# eval mol 360
# eval mol 361
# eval mol 362
# eval mol 363
# eval mol 364
# eval mol 365
# eval mol 366
# eval mol 367
# eval mol 368
# eval mol 369
# eval mol 370
# eval mol 371
# eval mol 372
# eval mol 373
# eval mol 374
# eval mol 375
# eval mol 376
# eval mol 377
# eval mol 378
# eval mol 379
# eval mol 380
# eval mol 381
# eval mol 382
# eval mol 383
# eval mol 384
# eval mol 385
# eval mol 386
# eval mol 387
# eval mol 388
# eval mol 389
# eval mol 390
# eval mol 391
# eval mol 392
# eval mol 393
# eval mol 394
# eval mol 395
# eval mol 396
# eval mol 397
# eval mol 398
# eval mol 399
# eval mol 400
# eval mol 401
# eval mol 402
# eval mol 403
# eval mol 404
# eval mol 405
# eval mol 406
# eval mol 407
# eval mol 408
# eval mol 409
# eval mol 410
# eval mol 411
# eval mol 412
# eval mol 413
# eval mol 414
# eval mol 415
# eval mol 416
# eval mol 417
# eval mol 418
# eval mol 419
# eval mol 420
# eval mol 421
# eval mol 422
# eval mol 423
# eval mol 424
# eval mol 425
# eval mol 426
# eval mol 427
# eval mol 428
# eval mol 429
# eval mol 430
# eval mol 431
# eval mol 432
# eval mol 433
# eval mol 434
# eval mol 435
# eval mol 436
# eval mol 437
# eval mol 438
# eval mol 439
# eval mol 440
# eval mol 441
# eval mol 442
# eval mol 443
# eval mol 444
# eval mol 445
# eval mol 446
# eval mol 447
# eval mol 448
# eval mol 449
# eval mol 450
# eval mol 451
# eval mol 452
# eval mol 453
# eval mol 454
# eval mol 455
# eval mol 456
# eval mol 457
# eval mol 458
# eval mol 459
# eval mol 460
# eval mol 461
# eval mol 462
# eval mol 463
# eval mol 464
# eval mol 465
# eval mol 466
# eval mol 467
# eval mol 468
# eval mol 469
# eval mol 470
# eval mol 471
# eval mol 472
# eval mol 473
# eval mol 474
# eval mol 475
# eval mol 476
# eval mol 477
# eval mol 478
# eval mol 479
# eval mol 480
# eval mol 481
# eval mol 482
# eval mol 483
# eval mol 484
# eval mol 485
# eval mol 486
# eval mol 487
# eval mol 488
# eval mol 489
# eval mol 490
# eval mol 491
# eval mol 492
# eval mol 493
# eval mol 494
# eval mol 495
# eval mol 496
# eval mol 497
# eval mol 498
# eval mol 499

# %%
# top_500_surprise_mols = mols_from_df(best_sucos_surprise)
# top_500_surprise_mat = compare_mols_sucos(top_500_surprise_mols)
# Out:
# eval mol 0
# eval mol 1
# eval mol 2
# eval mol 3
# eval mol 4
# eval mol 5
# eval mol 6
# eval mol 7
# eval mol 8
# eval mol 9
# eval mol 10
# eval mol 11
# eval mol 12
# eval mol 13
# eval mol 14
# eval mol 15
# eval mol 16
# eval mol 17
# eval mol 18
# eval mol 19
# eval mol 20
# eval mol 21
# eval mol 22
# eval mol 23
# eval mol 24
# eval mol 25
# eval mol 26
# eval mol 27
# eval mol 28
# eval mol 29
# eval mol 30
# eval mol 31
# eval mol 32
# eval mol 33
# eval mol 34
# eval mol 35
# eval mol 36
# eval mol 37
# eval mol 38
# eval mol 39
# eval mol 40
# eval mol 41
# eval mol 42
# eval mol 43
# eval mol 44
# eval mol 45
# eval mol 46
# eval mol 47
# eval mol 48
# eval mol 49
# eval mol 50
# eval mol 51
# eval mol 52
# eval mol 53
# eval mol 54
# eval mol 55
# eval mol 56
# eval mol 57
# eval mol 58
# eval mol 59
# eval mol 60
# eval mol 61
# eval mol 62
# eval mol 63
# eval mol 64
# eval mol 65
# eval mol 66
# eval mol 67
# eval mol 68
# eval mol 69
# eval mol 70
# eval mol 71
# eval mol 72
# eval mol 73
# eval mol 74
# eval mol 75
# eval mol 76
# eval mol 77
# eval mol 78
# eval mol 79
# eval mol 80
# eval mol 81
# eval mol 82
# eval mol 83
# eval mol 84
# eval mol 85
# eval mol 86
# eval mol 87
# eval mol 88
# eval mol 89
# eval mol 90
# eval mol 91
# eval mol 92
# eval mol 93
# eval mol 94
# eval mol 95
# eval mol 96
# eval mol 97
# eval mol 98
# eval mol 99
# eval mol 100
# eval mol 101
# eval mol 102
# eval mol 103
# eval mol 104
# eval mol 105
# eval mol 106
# eval mol 107
# eval mol 108
# eval mol 109
# eval mol 110
# eval mol 111
# eval mol 112
# eval mol 113
# eval mol 114
# eval mol 115
# eval mol 116
# eval mol 117
# eval mol 118
# eval mol 119
# eval mol 120
# eval mol 121
# eval mol 122
# eval mol 123
# eval mol 124
# eval mol 125
# eval mol 126
# eval mol 127
# eval mol 128
# eval mol 129
# eval mol 130
# eval mol 131
# eval mol 132
# eval mol 133
# eval mol 134
# eval mol 135
# eval mol 136
# eval mol 137
# eval mol 138
# eval mol 139
# eval mol 140
# eval mol 141
# eval mol 142
# eval mol 143
# eval mol 144
# eval mol 145
# eval mol 146
# eval mol 147
# eval mol 148
# eval mol 149
# eval mol 150
# eval mol 151
# eval mol 152
# eval mol 153
# eval mol 154
# eval mol 155
# eval mol 156
# eval mol 157
# eval mol 158
# eval mol 159
# eval mol 160
# eval mol 161
# eval mol 162
# eval mol 163
# eval mol 164
# eval mol 165
# eval mol 166
# eval mol 167
# eval mol 168
# eval mol 169
# eval mol 170
# eval mol 171
# eval mol 172
# eval mol 173
# eval mol 174
# eval mol 175
# eval mol 176
# eval mol 177
# eval mol 178
# eval mol 179
# eval mol 180
# eval mol 181
# eval mol 182
# eval mol 183
# eval mol 184
# eval mol 185
# eval mol 186
# eval mol 187
# eval mol 188
# eval mol 189
# eval mol 190
# eval mol 191
# eval mol 192
# eval mol 193
# eval mol 194
# eval mol 195
# eval mol 196
# eval mol 197
# eval mol 198
# eval mol 199
# eval mol 200
# eval mol 201
# eval mol 202
# eval mol 203
# eval mol 204
# eval mol 205
# eval mol 206
# eval mol 207
# eval mol 208
# eval mol 209
# eval mol 210
# eval mol 211
# eval mol 212
# eval mol 213
# eval mol 214
# eval mol 215
# eval mol 216
# eval mol 217
# eval mol 218
# eval mol 219
# eval mol 220
# eval mol 221
# eval mol 222
# eval mol 223
# eval mol 224
# eval mol 225
# eval mol 226
# eval mol 227
# eval mol 228
# eval mol 229
# eval mol 230
# eval mol 231
# eval mol 232
# eval mol 233
# eval mol 234
# eval mol 235
# eval mol 236
# eval mol 237
# eval mol 238
# eval mol 239
# eval mol 240
# eval mol 241
# eval mol 242
# eval mol 243
# eval mol 244
# eval mol 245
# eval mol 246
# eval mol 247
# eval mol 248
# eval mol 249
# eval mol 250
# eval mol 251
# eval mol 252
# eval mol 253
# eval mol 254
# eval mol 255
# eval mol 256
# eval mol 257
# eval mol 258
# eval mol 259
# eval mol 260
# eval mol 261
# eval mol 262
# eval mol 263
# eval mol 264
# eval mol 265
# eval mol 266
# eval mol 267
# eval mol 268
# eval mol 269
# eval mol 270
# eval mol 271
# eval mol 272
# eval mol 273
# eval mol 274
# eval mol 275
# eval mol 276
# eval mol 277
# eval mol 278
# eval mol 279
# eval mol 280
# eval mol 281
# eval mol 282
# eval mol 283
# eval mol 284
# eval mol 285
# eval mol 286
# eval mol 287
# eval mol 288
# eval mol 289
# eval mol 290
# eval mol 291
# eval mol 292
# eval mol 293
# eval mol 294
# eval mol 295
# eval mol 296
# eval mol 297
# eval mol 298
# eval mol 299
# eval mol 300
# eval mol 301
# eval mol 302
# eval mol 303
# eval mol 304
# eval mol 305
# eval mol 306
# eval mol 307
# eval mol 308
# eval mol 309
# eval mol 310
# eval mol 311
# eval mol 312
# eval mol 313
# eval mol 314
# eval mol 315
# eval mol 316
# eval mol 317
# eval mol 318
# eval mol 319
# eval mol 320
# eval mol 321
# eval mol 322
# eval mol 323
# eval mol 324
# eval mol 325
# eval mol 326
# eval mol 327
# eval mol 328
# eval mol 329
# eval mol 330
# eval mol 331
# eval mol 332
# eval mol 333
# eval mol 334
# eval mol 335
# eval mol 336
# eval mol 337
# eval mol 338
# eval mol 339
# eval mol 340
# eval mol 341
# eval mol 342
# eval mol 343
# eval mol 344
# eval mol 345
# eval mol 346
# eval mol 347
# eval mol 348
# eval mol 349
# eval mol 350
# eval mol 351
# eval mol 352
# eval mol 353
# eval mol 354
# eval mol 355
# eval mol 356
# eval mol 357
# eval mol 358
# eval mol 359
# eval mol 360
# eval mol 361
# eval mol 362
# eval mol 363
# eval mol 364
# eval mol 365
# eval mol 366
# eval mol 367
# eval mol 368
# eval mol 369
# eval mol 370
# eval mol 371
# eval mol 372
# eval mol 373
# eval mol 374
# eval mol 375
# eval mol 376
# eval mol 377
# eval mol 378
# eval mol 379
# eval mol 380
# eval mol 381
# eval mol 382
# eval mol 383
# eval mol 384
# eval mol 385
# eval mol 386
# eval mol 387
# eval mol 388
# eval mol 389
# eval mol 390
# eval mol 391
# eval mol 392
# eval mol 393
# eval mol 394
# eval mol 395
# eval mol 396
# eval mol 397
# eval mol 398
# eval mol 399
# eval mol 400
# eval mol 401
# eval mol 402
# eval mol 403
# eval mol 404
# eval mol 405
# eval mol 406
# eval mol 407
# eval mol 408
# eval mol 409
# eval mol 410
# eval mol 411
# eval mol 412
# eval mol 413
# eval mol 414
# eval mol 415
# eval mol 416
# eval mol 417
# eval mol 418
# eval mol 419
# eval mol 420
# eval mol 421
# eval mol 422
# eval mol 423
# eval mol 424
# eval mol 425
# eval mol 426
# eval mol 427
# eval mol 428
# eval mol 429
# eval mol 430
# eval mol 431
# eval mol 432
# eval mol 433
# eval mol 434
# eval mol 435
# eval mol 436
# eval mol 437
# eval mol 438
# eval mol 439
# eval mol 440
# eval mol 441
# eval mol 442
# eval mol 443
# eval mol 444
# eval mol 445
# eval mol 446
# eval mol 447
# eval mol 448
# eval mol 449
# eval mol 450
# eval mol 451
# eval mol 452
# eval mol 453
# eval mol 454
# eval mol 455
# eval mol 456
# eval mol 457
# eval mol 458
# eval mol 459
# eval mol 460
# eval mol 461
# eval mol 462
# eval mol 463
# eval mol 464
# eval mol 465
# eval mol 466
# eval mol 467
# eval mol 468
# eval mol 469
# eval mol 470
# eval mol 471
# eval mol 472
# eval mol 473
# eval mol 474
# eval mol 475
# eval mol 476
# eval mol 477
# eval mol 478
# eval mol 479
# eval mol 480
# eval mol 481
# eval mol 482
# eval mol 483
# eval mol 484
# eval mol 485
# eval mol 486
# eval mol 487
# eval mol 488
# eval mol 489
# eval mol 490
# eval mol 491
# eval mol 492
# eval mol 493
# eval mol 494
# eval mol 495
# eval mol 496
# eval mol 497
# eval mol 498
# eval mol 499

# %%
top_500_similar_mat=mat

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
m = np.array(top_500_similar_mat)
plt.imshow(m, interpolation='nearest', cmap='plasma')
plt.colorbar()
plt.show()

# %%
m = np.array(top_500_surprise_mat)
plt.imshow(m, interpolation='nearest', cmap='plasma')
plt.colorbar()
plt.show()

# %%
fig7, ax7 = plt.subplots()
ax7.set_title('Best SuCOS scores for similar and surprise sets')
ax7.boxplot([list(best_sucos_similar['best_sucos']), list(best_sucos_surprise['best_sucos'])])

plt.show()

# %%
fig7, ax7 = plt.subplots()
ax7.set_title('Best Tanimoto scores for similar and surprise sets')
ax7.boxplot([list(best_tanimoto_similar['best_tanimoto']), list(best_tanimoto_surprise['best_tanimoto'])])

plt.show()

# %%
# top_250_similar_diverse, inds_250sd = mols_from_morgan(top_500_similar_mols, 250)  
df250 = best_sucos_similar.iloc[inds_250sd]

# %%
df = df250.sort_values(by=['best_sucos'], ascending=False)

df250_mols = mols_from_df(df)
top_250_similar_diverse_mat = compare_mols_sucos(df250_mols)
# Out:
# eval mol 0
# eval mol 1
# eval mol 2
# eval mol 3
# eval mol 4
# eval mol 5
# eval mol 6
# eval mol 7
# eval mol 8
# eval mol 9
# eval mol 10
# eval mol 11
# eval mol 12
# eval mol 13
# eval mol 14
# eval mol 15
# eval mol 16
# eval mol 17
# eval mol 18
# eval mol 19
# eval mol 20
# eval mol 21
# eval mol 22
# eval mol 23
# eval mol 24
# eval mol 25
# eval mol 26
# eval mol 27
# eval mol 28
# eval mol 29
# eval mol 30
# eval mol 31
# eval mol 32
# eval mol 33
# eval mol 34
# eval mol 35
# eval mol 36
# eval mol 37
# eval mol 38
# eval mol 39
# eval mol 40
# eval mol 41
# eval mol 42
# eval mol 43
# eval mol 44
# eval mol 45
# eval mol 46
# eval mol 47
# eval mol 48
# eval mol 49
# eval mol 50
# eval mol 51
# eval mol 52
# eval mol 53
# eval mol 54
# eval mol 55
# eval mol 56
# eval mol 57
# eval mol 58
# eval mol 59
# eval mol 60
# eval mol 61
# eval mol 62
# eval mol 63
# eval mol 64
# eval mol 65
# eval mol 66
# eval mol 67
# eval mol 68
# eval mol 69
# eval mol 70
# eval mol 71
# eval mol 72
# eval mol 73
# eval mol 74
# eval mol 75
# eval mol 76
# eval mol 77
# eval mol 78
# eval mol 79
# eval mol 80
# eval mol 81
# eval mol 82
# eval mol 83
# eval mol 84
# eval mol 85
# eval mol 86
# eval mol 87
# eval mol 88
# eval mol 89
# eval mol 90
# eval mol 91
# eval mol 92
# eval mol 93
# eval mol 94
# eval mol 95
# eval mol 96
# eval mol 97
# eval mol 98
# eval mol 99
# eval mol 100
# eval mol 101
# eval mol 102
# eval mol 103
# eval mol 104
# eval mol 105
# eval mol 106
# eval mol 107
# eval mol 108
# eval mol 109
# eval mol 110
# eval mol 111
# eval mol 112
# eval mol 113
# eval mol 114
# eval mol 115
# eval mol 116
# eval mol 117
# eval mol 118
# eval mol 119
# eval mol 120
# eval mol 121
# eval mol 122
# eval mol 123
# eval mol 124
# eval mol 125
# eval mol 126
# eval mol 127
# eval mol 128
# eval mol 129
# eval mol 130
# eval mol 131
# eval mol 132
# eval mol 133
# eval mol 134
# eval mol 135
# eval mol 136
# eval mol 137
# eval mol 138
# eval mol 139
# eval mol 140
# eval mol 141
# eval mol 142
# eval mol 143
# eval mol 144
# eval mol 145
# eval mol 146
# eval mol 147
# eval mol 148
# eval mol 149
# eval mol 150
# eval mol 151
# eval mol 152
# eval mol 153
# eval mol 154
# eval mol 155
# eval mol 156
# eval mol 157
# eval mol 158
# eval mol 159
# eval mol 160
# eval mol 161
# eval mol 162
# eval mol 163
# eval mol 164
# eval mol 165
# eval mol 166
# eval mol 167
# eval mol 168
# eval mol 169
# eval mol 170
# eval mol 171
# eval mol 172
# eval mol 173
# eval mol 174
# eval mol 175
# eval mol 176
# eval mol 177
# eval mol 178
# eval mol 179
# eval mol 180
# eval mol 181
# eval mol 182
# eval mol 183
# eval mol 184
# eval mol 185
# eval mol 186
# eval mol 187
# eval mol 188
# eval mol 189
# eval mol 190
# eval mol 191
# eval mol 192
# eval mol 193
# eval mol 194
# eval mol 195
# eval mol 196
# eval mol 197
# eval mol 198
# eval mol 199
# eval mol 200
# eval mol 201
# eval mol 202
# eval mol 203
# eval mol 204
# eval mol 205
# eval mol 206
# eval mol 207
# eval mol 208
# eval mol 209
# eval mol 210
# eval mol 211
# eval mol 212
# eval mol 213
# eval mol 214
# eval mol 215
# eval mol 216
# eval mol 217
# eval mol 218
# eval mol 219
# eval mol 220
# eval mol 221
# eval mol 222
# eval mol 223
# eval mol 224
# eval mol 225
# eval mol 226
# eval mol 227
# eval mol 228
# eval mol 229
# eval mol 230
# eval mol 231
# eval mol 232
# eval mol 233
# eval mol 234
# eval mol 235
# eval mol 236
# eval mol 237
# eval mol 238
# eval mol 239
# eval mol 240
# eval mol 241
# eval mol 242
# eval mol 243
# eval mol 244
# eval mol 245
# eval mol 246
# eval mol 247
# eval mol 248
# eval mol 249

# %%
m = np.array(top_250_similar_diverse_mat)
plt.imshow(m, interpolation='nearest', cmap='plasma')
plt.colorbar()
plt.show()

# %%
nl = []
for l in top_500_similar_mat[:250]:
    nl.append(l[:250])
m = np.array(nl)
plt.imshow(m, interpolation='nearest', cmap='plasma')
plt.colorbar()
plt.show()

# %%
fig7, ax7 = plt.subplots()
ax7.set_title('Best SuCOS scores for similar_diverse_250 and similar_500')
ax7.boxplot([list(df['best_sucos']), list(best_sucos_similar['best_sucos'])])

plt.show()

# %%
best_sucos_surprise.iloc[:250].to_csv('/Users/res3/michellab/XChem-examples/KALRNA/XX02KALRNA-x1376_1/250_surprise_sucos.csv')

# %%
df.to_csv('/Users/res3/michellab/XChem-examples/KALRNA/XX02KALRNA-x1376_1/250_similar_sucos_diverse.csv')

# %%
writer = Chem.SDWriter('/Users/res3/michellab/XChem-examples/KALRNA/XX02KALRNA-x1376_1/250_similar_sucos_diverse.sdf')
for mol in df250_mols:
    writer.write(mol)

# %%
writer = Chem.SDWriter('/Users/res3/michellab/XChem-examples/KALRNA/XX02KALRNA-x1376_1/250_surprise_sucos.sdf')
for mol in top_500_surprise_mols[:250]:
    writer.write(mol)

# %%
best_tanimoto_similar
# Out:
#           candidate_name                                   candidate_smiles  \
# 568  GDP-similar-rsn_480  CN(C)[S@@](C)(=O)=NS(=O)(=O)N1CC(n2cnc3c(N)nc(...
# 272  GDP-similar-rsn_716   COCC(C)(O)C(=O)NCC1COCCN1C(=O)c1nc(N)cc(=O)[nH]1
# 818  GDP-similar-rsn_528  CN(CC(=O)NCC1COCCN1C(=O)c1nc(N)cc(=O)[nH]1)S(C...
# 279  GDP-similar-rsn_788  CC(C(=O)NCC1COCCN1C(=O)c1nc(N)cc(=O)[nH]1)S(N)...
# 774  GDP-similar-rsn_932      COCC(O)C(=O)NCC1COCCN1C(=O)c1nc(N)cc(=O)[nH]1
# 645  GDP-similar-rsn_403  CP(C)(=O)C(O)C(=O)NCC1COCCN1C(=O)c1nc(N)cc(=O)...
# 481  GDP-similar-rsn_269  CC(C)(CCS(=O)(=O)N1CC(n2cnc3c(N)nc(N)nc32)C1)S...
# 291  GDP-similar-rsn_174  CN(CC1COCCN1C(=O)c1nc(Cl)c(=O)[nH]c1N)C(=O)C(C...
# 883  GDP-similar-rsn_786  Nc1cc(=O)[nH]c(C(=O)N2CCOCC2CNC(=O)CCS(N)(=O)=...
# 668  GDP-similar-rsn_207       Nc1nc(N)c2ncn(C3CN(C(=O)CCc4nnn[n-]4)C3)c2n1
# 441  GDP-similar-rsn_423   COC(C)C(O)C(=O)NCC1COCCN1C(=O)c1nc(N)cc(=O)[nH]1
# 339  GDP-similar-rsn_123  Nc1cc(=O)[nH]c(C(=O)N2CCOCC2CNC(=O)CCC[N+](=O)...
# 559  GDP-similar-rsn_384       COCCOCC(=O)NCC1COCCN1C(=O)c1nc(N)cc(=O)[nH]1
# 965  GDP-similar-rsn_252  CC(C(=O)NCC1CN(C(=O)c2nc(Cl)c(=O)[nH]c2N)CCO1)...
# 351   GDP-similar-rsn_17  CN(CC1COCCN1C(=O)c1nc(N)cc(=O)[nH]1)C(=O)C(C)(...
# 468  GDP-similar-rsn_911  CCS(=O)(=O)N(C)CC(=O)NCC1COCCN1C(=O)c1nc(N)cc(...
# 344  GDP-similar-rsn_171  CN(CC1COCCN1C(=O)c1nc(N)cc(=O)[nH]1)C(=O)CCC[N...
# 595  GDP-similar-rsn_736       COC(=O)NC(C)C(=O)N1CC(n2cnc3c(N)nc(N)nc32)C1
# 532  GDP-similar-rsn_649  CNS(=O)(=O)CCC(=O)NCC1COCCN1C(=O)c1nc(N)cc(=O)...
# 844  GDP-similar-rsn_734    CN(CC(=O)N1CC(n2cnc3c(N)nc(N)nc32)C1)S(C)(=O)=O
# 318  GDP-similar-rsn_775          Nc1nc(N)c2ncn(C3CN(C(=O)CC4COCCO4)C3)c2n1
# 72   GDP-similar-rsn_974  CC(C(=O)N(C)CC1COCCN1C(=O)c1nc(N)cc(=O)[nH]1)S...
# 825  GDP-similar-rsn_301  CNS(=O)(=O)CC(=O)NCC1COCCN1C(=O)c1nc(N)cc(=O)[...
# 890  GDP-similar-rsn_756  CC(C)(CCC(=O)N1CC(n2cnc3c(N)nc(N)nc32)C1)[N+](...
# 739  GDP-similar-rsn_506          Nc1nc(N)c2ncn(C3CN(C(=O)CCOC4COC4)C3)c2n1
# 341   GDP-similar-rsn_45  CN(CC1COCCN1C(=O)c1nc(Cl)c(=O)[nH]c1N)C(=O)CSS...
# 550  GDP-similar-rsn_962  CC(NS(C)(=O)=O)C(=O)NC1COCCN(C(=O)c2nc(N)cc(=O...
# 136  GDP-similar-rsn_970  COC1(C(=O)N2CC(n3cnc4c(N)nc(N)nc43)C2)CS(=O)(=...
# 497  GDP-similar-rsn_925  CN(CC(=O)NCC1COCCN1C(=O)c1nc(Cl)c(=O)[nH]c1N)S...
# 610  GDP-similar-rsn_929  CS(=O)(=O)NCC(=O)NC1COCCN(C(=O)c2nc(Cl)c(=O)[n...
# ..                   ...                                                ...
# 142  GDP-similar-rsn_958         COC(C)CN(C)C(=O)C1CCC(Cn2cnc3c(N)ncnc32)O1
# 697  GDP-similar-rsn_278          O=c1ccc2cc(OC3OC(CO)C(O)C(O)C3O)c(O)cc2o1
# 975   GDP-similar-rsn_31  CNS(=O)(=O)NCC(=O)NC(C)C1CN(C(=O)c2cc(C(N)=O)[...
# 679  GDP-similar-rsn_706  Nc1ncnc2c1ncn2CC1CCC(C(=O)NCCS(=O)(=O)C(F)(F)F)O1
# 184  GDP-similar-rsn_372     CCOP(C)(=O)CCCNC(=O)C1CCC(Cn2cnc3c(N)ncnc32)O1
# 719  GDP-similar-rsn_737  NS(=O)(=O)NCC(=O)NCC1COCCN1C(=O)/C=C/c1c[nH]cn...
# 746  GDP-similar-rsn_560  CS(C)(=O)=NC(=O)C(=O)N[C@@H]1COCCN(C(=O)c2c[nH...
# 912  GDP-similar-rsn_618  CN(C)S(=O)(=O)CC(=O)N1CCC(n2cc(-c3cccc(CO)n3)n...
# 255  GDP-similar-rsn_140  CN(C)S(=O)(=O)N(C)CC(=O)NC1COCCN(C(=O)c2cc(C(N...
# 604   GDP-similar-rsn_32     COCCS(=O)(=O)CC(=O)N1CC(n2cnc3c(N)nc(N)nc32)C1
# 963  GDP-similar-rsn_936  CN(CC1CN(C(=O)c2cc(C(N)=O)[nH]n2)CCO1)C(=O)/C=...
# 161  GDP-similar-rsn_747    CON(C)C(=O)C(C)NC(=O)C1CCC(Cn2cnc3c(N)ncnc32)O1
# 868  GDP-similar-rsn_879   CCOC(=O)C(C)(O)CNC(=O)C1CCC(Cn2cnc3c(N)ncnc32)O1
# 363  GDP-similar-rsn_374  CN(C)S(=O)(=O)N(C)CC(=O)NCC1CN(C(=O)c2nc(N)cc(...
# 209  GDP-similar-rsn_277       COC(CS(=O)(=O)N1CC(n2cnc3c(N)nc(N)nc32)C1)OC
# 873  GDP-similar-rsn_903  COCCS(=O)(=O)CC(=O)NCC1COCCN1C(=O)/C=C/c1c[nH]...
# 809  GDP-similar-rsn_262  CN(C)S(=O)(=O)N(C)CC(=O)NC1COCCN(C(=O)c2c[nH]c...
# 320  GDP-similar-rsn_588     CNS(=O)(=O)NCCNC(=O)C1CCC(Cn2cnc3c(N)ncnc32)O1
# 555   GDP-similar-rsn_51             COCc1noc(C2CCC(Cn3cnc4c(N)ncnc43)O2)n1
# 147  GDP-similar-rsn_822  COCCS(=O)(=O)CC(=O)N(C)CC1CN(C(=O)c2nc(Cl)c(=O...
# 76   GDP-similar-rsn_643       CS(=O)(=O)CCNC(=O)C1CCC(Cn2cnc3c(N)ncnc32)O1
# 620  GDP-similar-rsn_835  NC(=O)c1cc(C(=O)N2CCOC(CNC(=O)CCS(N)(=O)=O)C2)...
# 447  GDP-similar-rsn_213  CN(CC1COCCN1C(=O)c1c[nH]c(N)nc1=O)C(=O)/C=C/S(...
# 75   GDP-similar-rsn_324  CCS(=O)(=O)NCC(=O)NCC1CN(C(=O)c2nc(Cl)c(=O)[nH...
# 915  GDP-similar-rsn_152      CNS(=O)(=O)CCNC(=O)C1CCC(Cn2cnc3c(N)ncnc32)O1
# 705   GDP-similar-rsn_99  CN(CC1COCCN1C(=O)c1nc(Cl)c(=O)[nH]c1N)C(=O)CNS...
# 888  GDP-similar-rsn_166  CN(CC1COCCN1C(=O)c1c[nH]c(N)nc1=O)C(=O)C(C)(C)...
# 599  GDP-similar-rsn_148         COCCOCC(=O)NCC1COCCN1C(=O)c1c[nH]c(N)nc1=O
# 323  GDP-similar-rsn_368   Cc1nc2cc(=O)[nH]n2c(C)c1CCC(=O)N(C)CCNS(C)(=O)=O
# 601  GDP-similar-rsn_203  Cc1nn(C2CCS(=O)(=O)C2)c(C)c1NC(=O)NNc1cc(Cl)nc...
#
#                              candidate_conformers_file initial_hit  \
# 568  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 272  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 818  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 279  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 774  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 645  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 481  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 291  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 883  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 668  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 441  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 339  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 559  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 965  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 351  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 468  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 344  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 595  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 532  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 844  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 318  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 72   /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 825  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 890  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 739  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 341  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 550  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 136  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 497  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 610  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# ..                                                 ...         ...
# 142  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 697  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 975  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 679  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 184  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 719  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 746  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 912  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 255  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 604  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 963  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 161  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 868  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 363  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 209  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 873  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 809  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 320  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 555  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 147  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 76   /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 620  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 447  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 75   /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 915  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 705  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 888  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 599  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 323  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
# 601  /Users/res3/michellab/XChem-examples/KALRNA/GD...     GDP.sdf
#
#      best_sucos  best_sucos_id  best_tanimoto  best_tanimoto_id
# 568    0.498266             58       0.308493                58
# 272    0.503332             13       0.313108                56
# 818    0.536982             71       0.321554                15
# 279    0.493532             46       0.323561                80
# 774    0.491385             84       0.330227                57
# 645    0.505651             58       0.335402                46
# 481    0.478874             96       0.335435                96
# 291    0.482321             65       0.339241                 0
# 883    0.516441              2       0.341361                30
# 668    0.450635             95       0.342236                95
# 441    0.536354             97       0.344627                55
# 339    0.492743             22       0.347568                57
# 559    0.505559             72       0.347570                88
# 965    0.514410             97       0.348271                74
# 351    0.546688             16       0.348763                16
# 468    0.548418             78       0.349908                16
# 344    0.511018             80       0.354276                75
# 595    0.451591             30       0.355323                30
# 532    0.503852             91       0.355556                25
# 844    0.454074             89       0.357951                89
# 318    0.462228             44       0.358440                44
# 72     0.536904              7       0.358732                41
# 825    0.504419             59       0.358800                91
# 890    0.420844             42       0.359438                42
# 739    0.486193             20       0.361398                20
# 341    0.520915             60       0.361868                60
# 550    0.505048             38       0.362902                34
# 136    0.455929             47       0.363250                47
# 497    0.549861             86       0.363360                45
# 610    0.512250             86       0.364040                16
# ..          ...            ...            ...               ...
# 142    0.430347             13       0.444932                94
# 697    0.424545             42       0.445023                54
# 975    0.469661             60       0.445034                51
# 679    0.487337             59       0.445248                65
# 184    0.409220             61       0.445634                61
# 719    0.465024             57       0.445658                57
# 746    0.460927             91       0.445723                18
# 912    0.420291             71       0.445727                71
# 255    0.512070             33       0.445818                27
# 604    0.421250             99       0.445819                77
# 963    0.469020             56       0.445966                87
# 161    0.426953             80       0.446013                11
# 868    0.441506              2       0.446245                35
# 363    0.508793             51       0.446253                51
# 209    0.461725             34       0.446462                71
# 873    0.446369             80       0.446676                 5
# 809    0.486038             70       0.446686                37
# 320    0.449564             50       0.446690                56
# 555    0.433901             18       0.446784                94
# 147    0.485000             41       0.446795                68
# 76     0.420648             95       0.446856                73
# 620    0.454619             41       0.446928                37
# 447    0.462989             11       0.447103                30
# 75     0.472067             95       0.447147                10
# 915    0.427157             22       0.447205                26
# 705    0.508887             16       0.447267                36
# 888    0.491130             58       0.447480                19
# 599    0.470440              4       0.447564                92
# 323    0.431998             74       0.447623                67
# 601    0.409587             10       0.447790                80
#
# [500 rows x 8 columns]

# %%
best_sucos_similar.to_csv('/Users/res3/michellab/XChem-examples/KALRNA/GDP_frags/GDP/500_similar_sucos.csv')
writer = Chem.SDWriter('/Users/res3/michellab/XChem-examples/KALRNA/GDP_frags/GDP/500_similar_sucos.sdf')
for mol in top_500_similar_mols:
    writer.write(mol)
